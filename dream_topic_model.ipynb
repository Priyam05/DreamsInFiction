# %%
# !pip install gensim==3.8.3
# Out:
# Collecting gensim==3.8.3
#   Downloading gensim-3.8.3-cp36-cp36m-macosx_10_9_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 274 kB/s eta 0:00:01
# Requirement already satisfied: six>=1.5.0 in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from gensim==3.8.3) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from gensim==3.8.3) (1.5.2)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from gensim==3.8.3) (2.2.1)
# Requirement already satisfied: numpy>=1.11.3 in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from gensim==3.8.3) (1.19.1)
# Requirement already satisfied: requests in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from smart-open>=1.8.1->gensim==3.8.3) (2.24.0)
# Requirement already satisfied: boto3 in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from smart-open>=1.8.1->gensim==3.8.3) (1.15.13)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim==3.8.3) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim==3.8.3) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim==3.8.3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim==3.8.3) (2020.6.20)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from boto3->smart-open>=1.8.1->gensim==3.8.3) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from boto3->smart-open>=1.8.1->gensim==3.8.3) (0.10.0)
# Requirement already satisfied: botocore<1.19.0,>=1.18.13 in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from boto3->smart-open>=1.8.1->gensim==3.8.3) (1.18.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/JackMac/opt/anaconda3/envs/chf20/lib/python3.6/site-packages (from botocore<1.19.0,>=1.18.13->boto3->smart-open>=1.8.1->gensim==3.8.3) (2.8.1)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.8.0
#     Uninstalling gensim-3.8.0:
#       Successfully uninstalled gensim-3.8.0
# Successfully installed gensim-3.8.3

# %%
import nltk
import re
import gensim
from gensim import corpora
import operator
import pandas as pd

nltk.download('stopwords')
from nltk.corpus import stopwords

import numpy as np
import random

random.seed(1)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/JackMac/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
full_dream = pd.read_csv("dreams.csv.1")
dream_content = full_dream['content']
dream_content
# Out:
# 0        In my dream, the first thing I remember was th...
# 1        The next thing I know, I'm in this big, fairly...
# 2        Last night's dreams are a little fuzzy in my m...
# 3        I woke up this morning knowing I had a dream i...
# 4        I remember being in Africa- a quiet wooded sce...
#                                ...
# 26338    Merrilee was joining the United Nations ______...
# 26339    Apparently I was coming home from Jackson and ...
# 26340    I've been having some really weird dreams late...
# 26341    I was in some kind of grassy, open space. I fe...
# 26342    I had a lot of catching up to do, and I cannot...
# Name: content, Length: 26343, dtype: object

# %%
def read_stopwords(filename):
    stopwords={}
    with open(filename) as file:
        for line in file:
            stopwords[line.rstrip()]=1
    return stopwords

# %%
stop_words = {k:1 for k in stopwords.words('english')}
stop_words["'s"]=1
stop_words["dream"]=1
stop_words=list(stop_words.keys())

# %%
def filter(word, stopwords):
    
    """ Function to exclude words from a text """
    
    # no stopwords
    if word in stopwords:
        return False
    
    # has to contain at least one letter
    if re.search("[A-Za-z]", word) is not None:
        return True
    
    return False

# %%
def dream_topic_preparation(dream_series, stopwords):
    docs = []
    for dream in dream_series:
        tokens=nltk.word_tokenize(dream.lower())
        tokens = [x for x in tokens if filter(x, stopwords)]
        docs.append(tokens)
        
    return docs

# %%
tokenized_dreams = dream_topic_preparation(dream_content, stop_words)

# %%
tokenized_dreams
# Out:
# [['first',
#   'thing',
#   'remember',
#   'nerdy',
#   'guy',
#   'goes',
#   'school',
#   'opinion',
#   'biggest',
#   'nerd',
#   'school',
#   'saw',
#   'girl',
#   'talking',
#   'sudden',
#   'kissed',
#   'event',
#   'dramatic',
#   'started',
#   'crying',
#   'selflessly',
#   'happened-',
#   'completely',
#   'beautiful',
#   'girl',
#   'kissed',
#   'complete',
#   'geek',
#   'touched',
#   'moment',
#   'think',
#   'fell',
#   'love',
#   'spot',
#   'realized',
#   'beautiful',
#   'girl',
#   "'d",
#   'ever',
#   'seen',
#   'later',
#   'caught',
#   'cafe',
#   'sort',
#   'sat',
#   'talked',
#   "n't",
#   'want',
#   'tell',
#   'much',
#   'liked',
#   'might',
#   'thought',
#   'trying',
#   'take',
#   'advantage',
#   'nice',
#   'girl',
#   'would',
#   "n't",
#   'want'],
#  ['next',
#   'thing',
#   'know',
#   "'m",
#   'big',
#   'fairly',
#   'dark',
#   'room',
#   'old',
#   'female',
#   'teacher',
#   'mrs.',
#   'jones',
#   'right',
#   'school',
#   'trip',
#   'vacation',
#   'state',
#   'looked',
#   'clock',
#   'soon',
#   'looked',
#   'clock',
#   'hour',
#   'hand',
#   'went',
#   'around',
#   'clock',
#   'faster',
#   'second',
#   'hand',
#   'normally',
#   'would',
#   'distorted',
#   'time',
#   'interesting',
#   'thing',
#   'dreams-',
#   'probably',
#   'salvador',
#   'dali',
#   'got',
#   'idea',
#   'painting',
#   'anyway',
#   'know',
#   'vacation',
#   'state',
#   'trip',
#   'missed',
#   'saw',
#   'mrs.',
#   'pappas',
#   'outside',
#   'asked',
#   "n't",
#   "n't",
#   'remember',
#   'told',
#   "n't",
#   'mention',
#   'distortion',
#   'time',
#   'seemed',
#   'completely',
#   'normal',
#   'like',
#   'oh',
#   'goes',
#   'time',
#   'fault',
#   'missed',
#   'trip'],
#  ['last',
#   'night',
#   'dreams',
#   'little',
#   'fuzzy',
#   'mind',
#   'remember',
#   'living',
#   'somewhere',
#   'seemingly',
#   'far',
#   'away',
#   'home-',
#   'likely',
#   'somewhere',
#   'country',
#   "n't",
#   'really',
#   'remember',
#   'buildings',
#   'remember',
#   'meeting',
#   'two',
#   'girls',
#   'thought',
#   'met',
#   'previously',
#   'dreams',
#   'guess',
#   'maybe',
#   'night',
#   'reason',
#   'wanted',
#   'really',
#   'friendly',
#   'felt',
#   'kind',
#   'personal',
#   'attachment',
#   "n't",
#   'remember',
#   'much',
#   'except',
#   'lived',
#   'far',
#   'away',
#   'although',
#   'seemed',
#   'far',
#   'away',
#   'home',
#   'think',
#   'even',
#   'wanted',
#   'keep',
#   'contact',
#   'away',
#   'reason',
#   'thinking',
#   'things',
#   'wanted',
#   'ask',
#   'next',
#   'time',
#   'saw',
#   'could',
#   'address/email',
#   'address',
#   'wanted',
#   'stay',
#   'friends',
#   'forever',
#   'went',
#   'look',
#   'gone-',
#   'left',
#   'gone',
#   'back',
#   'home',
#   'time',
#   'house',
#   'much',
#   'resembled',
#   'grandfather',
#   'house',
#   'dreams',
#   'weird',
#   'always',
#   'know',
#   'something',
#   'looks',
#   'familiar',
#   'guess',
#   "n't",
#   'supposed',
#   'really',
#   'make',
#   'connection',
#   'small',
#   'van',
#   'definitely',
#   'van',
#   'went',
#   'college',
#   'model',
#   'un',
#   'saw',
#   'someone',
#   'get',
#   'inside',
#   'mr.',
#   'rosetti',
#   'think',
#   'far',
#   'knew',
#   'going',
#   'city',
#   'school',
#   'trip',
#   'van',
#   'seemed',
#   'like',
#   'really',
#   'big',
#   'fancy',
#   'bus',
#   'got',
#   'guy',
#   'lecturing',
#   'us',
#   'something',
#   'tired',
#   'half-asleep',
#   'within',
#   'weird',
#   'situation',
#   'kind',
#   'like',
#   'partial',
#   'within',
#   'lecturer',
#   'asked',
#   'question',
#   'imagined',
#   'knew',
#   'answer',
#   'raised',
#   'hand',
#   'finally',
#   'called',
#   'said',
#   "n't",
#   'know',
#   'answer',
#   'raised',
#   'hand',
#   'half',
#   'asleep',
#   'imagined',
#   'either',
#   'knew',
#   'answer',
#   'asking',
#   'different',
#   'question',
#   "n't",
#   'remember',
#   'anything'],
#  ['woke',
#   'morning',
#   'knowing',
#   'immediately',
#   'could',
#   "n't",
#   'remember',
#   'decided',
#   'let',
#   'body',
#   'relax',
#   'thoughts',
#   'flowed',
#   'back',
#   'head',
#   'remember',
#   'complaining',
#   'somebody',
#   'putting',
#   'barenaked',
#   'ladies',
#   'song',
#   'mcdonalds',
#   'girl',
#   'school',
#   'newspaper',
#   'believe',
#   'called',
#   'el',
#   'periodico',
#   'complaining',
#   'school',
#   'principal',
#   'trying',
#   'take',
#   'apart',
#   'lyrics',
#   'explain',
#   'offensive',
#   'course',
#   "n't",
#   'really',
#   'offended',
#   'newspaper',
#   'submission',
#   'still',
#   'complained',
#   'principal',
#   'mrs.',
#   'lear',
#   'actually',
#   'knew',
#   'newspaper',
#   'submission',
#   'first',
#   'place',
#   'making',
#   'still',
#   'felt',
#   'need',
#   'complain',
#   'remember',
#   'talking',
#   'person',
#   'blamed',
#   'submission',
#   'article',
#   'shows',
#   'image',
#   'little',
#   'lego',
#   'boat',
#   'told',
#   'something',
#   'ship',
#   'sunk',
#   'sink'],
#  ['remember',
#   'africa-',
#   'quiet',
#   'wooded',
#   'scene',
#   'outdoors',
#   'think',
#   'school',
#   'trip',
#   'night',
#   'rather',
#   'warm',
#   'air',
#   'felt',
#   'humid',
#   'remember',
#   'bedroom',
#   'one',
#   'much',
#   'like',
#   'many',
#   'frail',
#   'looking',
#   'boys',
#   'coming',
#   'in-',
#   'many',
#   'wearing',
#   'smallest',
#   'bit',
#   'clothing',
#   'felt',
#   'rather',
#   'bad',
#   'realized',
#   'hard',
#   'would',
#   'live',
#   'like',
#   'least',
#   'beds',
#   'room',
#   'boys',
#   'got',
#   'bed',
#   'also',
#   'seemed',
#   'like',
#   'would',
#   'crowded',
#   'also',
#   'got',
#   'bed-',
#   "'d",
#   'barely',
#   'fit',
#   'like',
#   'room',
#   'remember',
#   'thinking',
#   'since',
#   'many',
#   'people',
#   'beds',
#   "'d",
#   'rather',
#   'sleep',
#   'floor',
#   "n't",
#   'say',
#   'word',
#   "'m",
#   'hotel',
#   'certain',
#   'doors',
#   "n't",
#   'able',
#   'open',
#   'maybe',
#   "n't",
#   'remember',
#   'much',
#   'recollection',
#   'makes',
#   'shiver',
#   'even',
#   'though',
#   "n't",
#   'seem',
#   'bad',
#   'first',
#   'experienced',
#   'recollection',
#   'trapped',
#   'somewhere',
#   'although',
#   "n't",
#   'feel',
#   'pressing',
#   'situation'],
#  ['dreamed',
#   'walking',
#   'middle',
#   'new',
#   'york',
#   'city',
#   'yet',
#   "n't",
#   'really',
#   'look',
#   'much',
#   'like',
#   'city',
#   "n't",
#   'enough',
#   'tall',
#   'buildings',
#   'people',
#   'came',
#   'area',
#   'bunch',
#   'homeless',
#   'kids',
#   'one',
#   'boys',
#   'asked',
#   "'d",
#   'willing',
#   'trade',
#   'dollar',
#   'quarter',
#   'looking',
#   'pocket',
#   'found',
#   'several',
#   'hundred',
#   'dollars',
#   'gave',
#   'dollar',
#   'told',
#   'could',
#   'keep',
#   'quarter',
#   'gave',
#   'anyway',
#   'girl',
#   'upon',
#   'seeing',
#   'bowl',
#   'top',
#   'trailer',
#   'wondered',
#   'food',
#   'unfortunately',
#   'answer',
#   "n't",
#   'food',
#   'bowl',
#   'idea',
#   'came',
#   'could',
#   'take',
#   'ghetto',
#   'area',
#   'could',
#   'show',
#   'better',
#   'life',
#   'could',
#   'fun',
#   'asked',
#   "'d",
#   'like',
#   'come',
#   'admitted',
#   'money',
#   'said',
#   'would',
#   'reason',
#   'one',
#   'friends',
#   'came',
#   'us',
#   'walking',
#   'decided',
#   'ask',
#   'telephone',
#   'number',
#   'gave',
#   'really',
#   'weird',
#   'answer',
#   'although',
#   'start',
#   'area',
#   'code',
#   'something',
#   'like',
#   '611-832f-9',
#   'dt',
#   'told',
#   "n't",
#   'know',
#   'comma',
#   'telephone',
#   'told',
#   "n't",
#   'either',
#   'looking',
#   'telephone',
#   'found',
#   'one',
#   'five',
#   'six',
#   'symbols',
#   'key',
#   'told',
#   'number',
#   'dorm',
#   'something',
#   'like',
#   "n't",
#   'even',
#   'think',
#   'homeless',
#   'probably',
#   "n't",
#   'old',
#   'enough',
#   'go',
#   'college',
#   'lost',
#   'sight',
#   'one',
#   'point',
#   'decided',
#   'call',
#   'one',
#   'many',
#   'nearby',
#   'phones',
#   'course',
#   'called',
#   'number',
#   'expect',
#   "'m",
#   'really',
#   'calling',
#   'telephone',
#   "'m",
#   'calling',
#   'her-',
#   'nearest',
#   'telephone',
#   'would',
#   'probably',
#   'ring',
#   'guess',
#   'picked',
#   'phone',
#   'came',
#   'view',
#   'told',
#   "'d",
#   'looking',
#   'went',
#   'amusement',
#   'park',
#   'got',
#   'ride',
#   "'re",
#   'sitting',
#   'waist',
#   'water',
#   "n't",
#   'know',
#   'ride',
#   'supposed',
#   'point',
#   'girl',
#   'fact',
#   'know',
#   'name',
#   'probably',
#   'julia',
#   'first',
#   'name',
#   'comes',
#   'mind',
#   'thought',
#   'girl',
#   'started',
#   'floating',
#   'air',
#   'seemed',
#   'rather',
#   'normal',
#   'experience',
#   'said',
#   'oh',
#   'stop',
#   'floating',
#   "n't",
#   'remember',
#   'happened',
#   'except',
#   'gone',
#   'outside',
#   'amusement',
#   'park',
#   'computer',
#   'eccentric',
#   'type',
#   'computer',
#   'typing',
#   'song',
#   'lyrics',
#   'computer',
#   'song',
#   'lyrics',
#   'amazed',
#   'typing',
#   'really',
#   'good',
#   'lyrics',
#   'without',
#   'really',
#   'thinking',
#   'typing',
#   'often',
#   'try',
#   'write',
#   'song',
#   'lyrics',
#   'real',
#   'life',
#   'never',
#   'sound',
#   'right',
#   'even',
#   'though',
#   'think',
#   'deeply',
#   "'m",
#   'going',
#   'write',
#   'miraculously',
#   'perfect',
#   'song',
#   'lyrics',
#   'typed',
#   "'m",
#   'sure',
#   'good',
#   'would',
#   'sounded',
#   'heard',
#   'physical',
#   'world',
#   'interesting',
#   'little',
#   'program',
#   'computer',
#   'allowed',
#   'integrate',
#   'lyrics',
#   'actual',
#   'song',
#   'pressing',
#   'button',
#   'lyrics',
#   'sounded',
#   'excellent',
#   'put',
#   'music-',
#   'fact',
#   'think',
#   'voice',
#   'heard',
#   'singing',
#   'lyrics',
#   'none',
#   'steven',
#   'page',
#   'lead',
#   'vocalist',
#   'barenaked',
#   'ladies',
#   'song',
#   'yet',
#   'sounded',
#   'like',
#   'something',
#   'barenaked',
#   'ladies',
#   'might',
#   'done-',
#   'one',
#   'real',
#   'life',
#   'goals',
#   'write',
#   'song',
#   'comparable',
#   'barenaked',
#   'ladies',
#   'well',
#   'next',
#   'thing',
#   'remember',
#   'room',
#   'seeing',
#   'girl',
#   'floated',
#   'away',
#   'people',
#   'sat',
#   'couch',
#   'opposite',
#   'one',
#   'sitting',
#   'waved'],
#  ['first',
#   'memory',
#   'seeing',
#   'blonde',
#   'girl',
#   'looked',
#   'familiar',
#   'asked',
#   'name',
#   'said',
#   'michelle',
#   'playfully',
#   'jumped',
#   'acted',
#   'surprised',
#   'said',
#   'oh',
#   'sorry',
#   'thought',
#   'another',
#   'michelle',
#   'said',
#   'name',
#   'michelle',
#   'senior',
#   'school',
#   'last',
#   'name',
#   'donõt',
#   'know',
#   'anyone',
#   'named',
#   'michelle',
#   'yet',
#   'name',
#   'sounded',
#   'familiar',
#   'even',
#   'point',
#   'checked',
#   'old',
#   'yearbook',
#   'someone',
#   'name',
#   'woke',
#   'without',
#   'success',
#   'probably',
#   'related',
#   'alex',
#   'way',
#   'shadow',
#   'prep',
#   'academy',
#   'wanted',
#   'shadow',
#   'went',
#   'someone',
#   'else',
#   'instead',
#   'supposed',
#   'class',
#   'went',
#   'another',
#   'room',
#   'look',
#   'michelle',
#   'instead',
#   'found',
#   'people',
#   'presumably',
#   'teachers',
#   'since',
#   'one',
#   'person',
#   'knew',
#   'mr.',
#   'grant',
#   'others',
#   'seemed',
#   'know',
#   'shook',
#   'hand',
#   "n't",
#   'recognize'],
#  ['walking',
#   'hospital',
#   'people',
#   'life',
#   'support',
#   'cords',
#   'connecting',
#   'support',
#   'went',
#   'place',
#   'could',
#   'walk',
#   'since',
#   'lights',
#   'rather',
#   'low',
#   'afraid',
#   'might',
#   'accidentally',
#   'knock',
#   'one',
#   'plugs',
#   'someone',
#   'might',
#   'trip',
#   'teachers',
#   'mrs.',
#   'pappas',
#   'mr.',
#   'dell',
#   'think',
#   'mrs.',
#   'pappas',
#   'told',
#   'turn',
#   'dial',
#   'press',
#   'button',
#   "n't",
#   'hear',
#   'whether',
#   'said',
#   "n't",
#   'press',
#   'button',
#   'press',
#   "n't",
#   'know',
#   'button',
#   'thought',
#   'might',
#   'crucial',
#   'consequence',
#   "n't",
#   'follow',
#   'directions',
#   'called',
#   'walking',
#   'away',
#   "n't",
#   'answer',
#   'mr.',
#   'dell',
#   'walking',
#   'behind',
#   'called',
#   'mr.',
#   'dell',
#   'said',
#   "'d",
#   'get',
#   'mrs.',
#   'pappas',
#   'come',
#   'back',
#   'tell',
#   'never',
#   'far',
#   'remember',
#   'remember',
#   'sitting',
#   'table',
#   'probably',
#   'outside',
#   'eating',
#   'mrs.',
#   'saint',
#   'others',
#   'remember',
#   'could',
#   "n't",
#   'hear',
#   'much',
#   'keep',
#   'asking',
#   'kids',
#   'nearby',
#   'table',
#   'repeat',
#   'saying',
#   'me-',
#   'people',
#   'laughed',
#   'told',
#   'forget',
#   'really',
#   'wanted',
#   'know',
#   'talking',
#   'felt',
#   'excluded',
#   'also',
#   'remember',
#   'mrs.',
#   'jones',
#   'showing',
#   'something',
#   'outside',
#   'school',
#   "n't",
#   'remember',
#   'probably',
#   'fell',
#   'asleep',
#   "'d",
#   'gotten',
#   'back',
#   'plainview',
#   'high',
#   'school',
#   "'d",
#   'seen',
#   'old',
#   'teachers'],
#  ['remember',
#   'really',
#   'involved',
#   'like',
#   'movie',
#   "'m",
#   'watching',
#   'nobody',
#   'else',
#   'notices',
#   "'m",
#   'boy',
#   'think',
#   'girl',
#   'either',
#   'sister',
#   'mother',
#   'probably',
#   'boy',
#   'taken',
#   'somewhere',
#   'ceiling',
#   'basement',
#   'think',
#   'grandfather',
#   'basement',
#   'evil',
#   'superman',
#   'look-alike',
#   'girl',
#   "n't",
#   'know',
#   'happening',
#   'little',
#   'brother/son',
#   'foggy',
#   'memory',
#   'ca',
#   "n't",
#   'describe',
#   'next',
#   'thing',
#   'know',
#   "'m",
#   'kitchen',
#   'bunch',
#   'people',
#   'there-',
#   'electrical',
#   'unit',
#   'something',
#   'near',
#   'door',
#   'remember',
#   'although',
#   "n't",
#   'know',
#   'anything',
#   'sort',
#   'slid',
#   'house',
#   "n't",
#   'exactly',
#   'remember',
#   'almost',
#   'like',
#   'waterslide',
#   'maybe',
#   'fell',
#   'side',
#   'driveway',
#   'suddenly',
#   'realized',
#   'clothes',
#   'point',
#   'everybody',
#   'getting',
#   'ready',
#   'start',
#   'fantasy',
#   'baseball',
#   'draft',
#   'first',
#   'draft',
#   'pick',
#   'went',
#   'jethros',
#   'i.e',
#   'jethro',
#   'tull',
#   'last',
#   'guitar',
#   'lesson',
#   'told',
#   'guitar',
#   'teacher',
#   "n't",
#   'really',
#   'like',
#   'jethro',
#   'tull',
#   'said',
#   'never',
#   'heard',
#   'anyone',
#   "n't"],
#  ['takes',
#   'place',
#   'night',
#   "'m",
#   'running',
#   'continuously',
#   'place',
#   'looks',
#   'sort',
#   'like',
#   'town',
#   'half',
#   'realize',
#   "'m",
#   'dreaming',
#   'really',
#   'remember',
#   'thinking',
#   'easy',
#   'run',
#   'without',
#   'getting',
#   'breath',
#   'fun',
#   'running',
#   'dreams',
#   'although',
#   'looked',
#   'lot',
#   'like',
#   'town',
#   'get',
#   'feeling',
#   'point',
#   'long',
#   'way',
#   'hometown',
#   'remember',
#   'asking',
#   'someone',
#   'bank',
#   'since',
#   'knew',
#   'dreaming',
#   'wanted',
#   'rob',
#   'million',
#   'dollars',
#   'bank',
#   'play',
#   'liar',
#   'liar',
#   'called',
#   "n't",
#   'exactly',
#   'understand',
#   'except',
#   'movie',
#   'liar',
#   'liar',
#   'jim',
#   'carey',
#   'played',
#   'part',
#   'lawyer',
#   'could',
#   "n't",
#   'tell',
#   'truth',
#   'fun',
#   'playing',
#   'cops',
#   'robbers',
#   'sleep',
#   'real',
#   'never',
#   'got',
#   'bank',
#   'anything',
#   'really',
#   'knew',
#   'dreaming',
#   'would',
#   'known',
#   "n't",
#   'need',
#   'money',
#   'world',
#   'done',
#   'whatever',
#   'wanted',
#   'oh',
#   'also',
#   'things',
#   'lucid',
#   'dreaming',
#   'thought',
#   'remember',
#   'thinking',
#   'one',
#   'point',
#   'dreaming',
#   'wonder',
#   'hypnotize',
#   "'m",
#   'dreaming',
#   "'ll",
#   'different',
#   'way',
#   'wake',
#   'someone',
#   'told',
#   'thinking',
#   'idiosyncrasies',
#   'real',
#   'life',
#   'make',
#   'stronger',
#   'fading',
#   'somehow',
#   'worked',
#   'crazy',
#   'probably',
#   'worked',
#   'power',
#   'suggestion',
#   'besides',
#   'thinking',
#   'things',
#   'like',
#   "n't",
#   'shower',
#   'enough',
#   'idiosyncrasies'],
#  ['dreamed',
#   'big',
#   'room',
#   'lots',
#   'people',
#   'tables',
#   "n't",
#   'see',
#   'food',
#   'bernice',
#   'brief',
#   'sexual',
#   'scene',
#   'us',
#   'guess',
#   'school',
#   'school',
#   'event',
#   'afraid',
#   'everyone',
#   'seen',
#   'could',
#   'kicked',
#   'school',
#   'pretended',
#   'whole',
#   'thing',
#   'show',
#   'walking',
#   'around',
#   'every',
#   'table',
#   'asking',
#   'everyone',
#   'like',
#   'show',
#   "n't",
#   'feel',
#   'like',
#   'anyone',
#   'time',
#   'felt',
#   'looking',
#   'would',
#   'catch',
#   'minute',
#   'girl',
#   'sat',
#   'next',
#   'told',
#   'surprise',
#   "'ll",
#   'love',
#   'forever',
#   "n't",
#   'say',
#   'things',
#   'believe',
#   'really',
#   'mean',
#   'sound',
#   'like',
#   'holden',
#   'caulfield',
#   'catcher',
#   'rye',
#   'know-',
#   'know',
#   'exactly',
#   'kid',
#   'felt',
#   'heard',
#   'somebody',
#   'call',
#   'name',
#   'knew',
#   "'d",
#   'huge',
#   'trouble',
#   'strange',
#   'thing',
#   'though',
#   "n't",
#   'name',
#   'ca',
#   "n't",
#   'remember',
#   'called',
#   'seemed',
#   'natural',
#   'like',
#   'really',
#   'name',
#   'brought',
#   'girl',
#   'nearest',
#   'door',
#   'downstairs',
#   'kept',
#   'telling',
#   'run',
#   'faster',
#   "n't",
#   'run',
#   'away',
#   'felt',
#   'safer',
#   'around',
#   'far',
#   'remember',
#   'got',
#   'remember',
#   'thinking',
#   'woken',
#   'coming',
#   'outside',
#   'house',
#   'see',
#   'school',
#   'bus',
#   'driveway',
#   'thought',
#   'bus',
#   'might',
#   'realized',
#   'case',
#   'could',
#   'anywhere',
#   'world',
#   'looked',
#   'location',
#   'side',
#   'said',
#   'somewhere',
#   'ca',
#   'instead',
#   'making',
#   'mean',
#   'west',
#   'coast',
#   'thought',
#   'meant',
#   'central',
#   'america',
#   'also',
#   'remember',
#   'getting',
#   'phone',
#   'call',
#   'called',
#   'studio',
#   'radio',
#   'station',
#   'abcd',
#   'nearby',
#   'university-',
#   "n't",
#   'small',
#   'studio',
#   'room',
#   'like',
#   'big',
#   'gymnasium',
#   'remember',
#   'everybody',
#   'clothes',
#   'guys',
#   'shirts',
#   'think',
#   'main',
#   'guy',
#   'reminded',
#   'one',
#   'early',
#   'morning',
#   'guys',
#   'waaf'],
#  ['first',
#   'thing',
#   'remember',
#   'holding',
#   'cd',
#   'hand',
#   'sudden',
#   'able',
#   'hear',
#   'music',
#   'perfectly',
#   'head',
#   'amazed',
#   'ability',
#   'although',
#   "n't",
#   'sure',
#   'thought',
#   'awake',
#   'asleep',
#   'time',
#   "n't",
#   'remember',
#   'disc',
#   'listening',
#   'either',
#   'remember',
#   'brother',
#   'saying',
#   'something',
#   'band',
#   'called',
#   'something',
#   'hill',
#   'thought',
#   'band',
#   'sugar',
#   'hill',
#   'dc',
#   'talk',
#   'sings',
#   'one',
#   'albums',
#   'think',
#   'going',
#   'put',
#   'dc',
#   'talk',
#   'cd',
#   'player',
#   'point',
#   'remember',
#   'going',
#   'unconscious',
#   'started',
#   'seeing',
#   'pictures',
#   'head',
#   'something',
#   'really',
#   'felt',
#   'like',
#   'another',
#   'form',
#   'consciousness',
#   'next',
#   'thing',
#   'know',
#   "'m",
#   'bed',
#   'reading',
#   'come',
#   'across',
#   'passage',
#   'never',
#   'really',
#   'know',
#   'saying',
#   'every',
#   'time',
#   'read',
#   'go',
#   'unconscious',
#   'read',
#   'passage',
#   'several',
#   'times',
#   "'m",
#   'never',
#   'able',
#   'finish',
#   'black',
#   'another',
#   'world',
#   'temporarily',
#   'seemed',
#   'like',
#   'seconds',
#   'time',
#   'anyway',
#   'finally',
#   'able',
#   'read',
#   'remember',
#   'something',
#   'general',
#   'effect',
#   'paraphrasing',
#   'according',
#   'research',
#   'john',
#   'smith',
#   'every',
#   'time',
#   'certain',
#   'phrase',
#   'written',
#   'people',
#   'proven',
#   'go',
#   'unconscious',
#   'really',
#   'believe',
#   'something',
#   'happen',
#   'think',
#   'still',
#   'blacked',
#   'even',
#   'disappointment',
#   'somebody',
#   'actually',
#   'telling',
#   'technique',
#   'placebo',
#   'really',
#   'could',
#   'killed',
#   'guy',
#   'spoiling',
#   'least',
#   'able',
#   'read',
#   'time-',
#   'enough',
#   'understand',
#   'saying'],
#  ['remember',
#   'walking',
#   'physics',
#   'class',
#   'teacher',
#   'letting',
#   'make',
#   'test',
#   'told',
#   'specifically',
#   'got',
#   'many',
#   'problems',
#   'wrong',
#   'wouldnõt',
#   'fair',
#   'let',
#   'test',
#   'home',
#   'youõll',
#   'get',
#   'least',
#   'couple',
#   'problems',
#   'done',
#   'remember',
#   'thinking',
#   "n't",
#   'tell',
#   'us',
#   'things',
#   'beforehand',
#   'iõm',
#   'searching',
#   'problems',
#   'pen',
#   'everything',
#   'could',
#   "n't",
#   'even',
#   'find',
#   'everything',
#   'remember',
#   'giving',
#   'paper',
#   'said',
#   'pretty',
#   'much',
#   "'m",
#   'disappointed',
#   "n't",
#   'even',
#   'know',
#   "'re",
#   'something',
#   'else',
#   'sequence',
#   'something',
#   'little',
#   'positive',
#   'maybe',
#   "n't",
#   'waking',
#   'impression',
#   '.i',
#   "n't",
#   'really',
#   'remember',
#   'part',
#   'remember',
#   'trip',
#   'somewhere',
#   'girl',
#   'identity',
#   "'m",
#   'unsure',
#   "n't",
#   'remember',
#   'anything'],
#  ['someone',
#   'told',
#   'missed',
#   'christmas-',
#   'balled',
#   'eyes',
#   'told',
#   "'d",
#   'still',
#   'get',
#   'presents',
#   'everything',
#   'kept',
#   'crying',
#   'saying',
#   'actually',
#   'think',
#   'happened',
#   'watching',
#   'something',
#   'tv',
#   'seemed',
#   'like',
#   'watching',
#   'people',
#   'room',
#   'television-like',
#   'screen',
#   'someone',
#   'came',
#   'broke',
#   'news',
#   'heartbroken'],
#  ['dreamed',
#   'going',
#   'sleep',
#   'within',
#   'purpose',
#   'recording',
#   'lucid',
#   'woke',
#   'device',
#   'let',
#   'easily',
#   'lucid',
#   'dreams',
#   'think',
#   'within',
#   'remember',
#   'thinking',
#   'lucid',
#   'somewhat',
#   'lucid',
#   'saw',
#   'words',
#   'posted',
#   'somewhere-',
#   'tried',
#   'memorize',
#   "'d",
#   'remember',
#   'woke',
#   "n't",
#   'remember',
#   'words',
#   'except',
#   'letter',
#   'e',
#   'probably',
#   'first',
#   'letter',
#   'two',
#   'words',
#   'words',
#   'memorized',
#   'remember',
#   'near',
#   'nurse',
#   'office',
#   'going',
#   'room',
#   'foot',
#   'ceiling',
#   'dust',
#   'floors',
#   'lot',
#   'army',
#   'men',
#   'eating',
#   'hanging',
#   'glad',
#   "n't",
#   'army',
#   'left',
#   'room',
#   'tried',
#   'hard',
#   'get',
#   'dusty',
#   'strange',
#   'feeling',
#   'camp',
#   'something',
#   "n't",
#   'going',
#   'able',
#   'wash',
#   'anyway',
#   'forget',
#   'happened',
#   'woke',
#   'semi-lucid',
#   'dream-dream',
#   'except',
#   'tried',
#   'record',
#   'words',
#   'could',
#   "n't",
#   'remember'],
#  ['video',
#   'store',
#   "n't",
#   'remember',
#   'thought',
#   "'m",
#   'really',
#   'lucid',
#   'heck',
#   'lady',
#   'behind',
#   'counter',
#   'smoking',
#   'said',
#   'rest',
#   'place',
#   'non-smoking',
#   'thought',
#   'strange',
#   'well',
#   'thought',
#   'wait',
#   'minute',
#   "'m",
#   'lucid',
#   "n't",
#   'standing',
#   'nothing',
#   'thought',
#   "'d",
#   'conjure',
#   'girl',
#   'remember',
#   'years',
#   'ago',
#   'remember',
#   'using',
#   'hands',
#   'saying',
#   'name',
#   'trying',
#   'get',
#   'appear',
#   'nothing',
#   'happened',
#   'thought',
#   'another',
#   'method',
#   'execution',
#   "'d",
#   'decided',
#   'waking',
#   'life',
#   'want',
#   'something',
#   'ca',
#   "n't",
#   "'ve",
#   'got',
#   'ta',
#   'ask',
#   'somebody',
#   'else-',
#   'especially',
#   'wise',
#   'man',
#   'mystic',
#   'someone',
#   'knows',
#   "'re",
#   "'d",
#   'ask',
#   'lady',
#   'behind',
#   'counter',
#   'knew',
#   'girl',
#   'lady',
#   'walked',
#   'end',
#   'store',
#   'girl',
#   'appeared',
#   'room',
#   'yet',
#   "n't",
#   'look',
#   'much',
#   'like',
#   'last',
#   'time',
#   'saw',
#   'ran',
#   'away'],
#  ['jamie',
#   'came',
#   'help',
#   'solace',
#   'remember',
#   'lying',
#   'bed',
#   'head',
#   'chest',
#   'area',
#   'stroking',
#   'head',
#   'remember',
#   'school',
#   'school',
#   'walking',
#   'train',
#   'tracks',
#   'bridge',
#   'knew',
#   'old',
#   'sturdy',
#   'something',
#   'gave',
#   'impression',
#   'grandfather',
#   'neighborhood',
#   "n't",
#   'look',
#   'anything',
#   'like',
#   'recalling',
#   'black',
#   'bag',
#   'filled',
#   'something',
#   'books',
#   'think',
#   'tripped',
#   'almost',
#   'fell',
#   'water-',
#   'grabbed',
#   'onto',
#   'pole',
#   'attached',
#   'bridge',
#   "n't",
#   'fall',
#   'remember',
#   'word',
#   'leer',
#   'spanish',
#   'read',
#   'flashing',
#   'eyes',
#   'remember',
#   'dreaming',
#   'parents',
#   'black',
#   'interesting',
#   'recognized',
#   'knew',
#   'possibly',
#   'previous',
#   'dreams'],
#  ['family',
#   'members',
#   'character',
#   'grandfather',
#   'setting',
#   'marriage',
#   'someone',
#   "'ve",
#   'never',
#   'met',
#   'really',
#   "n't",
#   'want',
#   'wanted',
#   'know',
#   'might',
#   'possibly',
#   'known',
#   'person',
#   'extremely',
#   'curious',
#   'whole',
#   'thing',
#   'promised',
#   "'d",
#   'go',
#   'eat',
#   'afterwards',
#   'got',
#   'early',
#   'enough',
#   "didn't-",
#   "n't",
#   'think',
#   'ever',
#   'showed',
#   'never',
#   'expected',
#   'upset-',
#   'mind',
#   'set',
#   'certain',
#   'restaurant',
#   'found',
#   'eat',
#   'home',
#   'furious',
#   'home',
#   'family',
#   'went',
#   'something',
#   'remember',
#   'trying',
#   'make',
#   'strawberry',
#   'milk',
#   'gone-',
#   'started',
#   'using',
#   'hot',
#   'water',
#   'faucet',
#   'realized',
#   'regular',
#   'milk',
#   'meant',
#   'hot',
#   'tried',
#   'turn',
#   'cold',
#   'water',
#   'coolest',
#   'got',
#   'luke',
#   'warm',
#   "n't",
#   'want',
#   'catch',
#   'making',
#   'strawberry',
#   'milk',
#   'although',
#   'brother',
#   'family',
#   'home',
#   'noticed',
#   'naked',
#   'grabbed',
#   'towel',
#   'doorknob',
#   'walked',
#   'door',
#   'kitchen',
#   'night',
#   'slightly',
#   'lucid',
#   'time',
#   'asked',
#   'mother',
#   'teach',
#   'telekinesis',
#   'also',
#   'mentioned',
#   'wanting',
#   'learn',
#   'materialize',
#   'objects',
#   'tried',
#   'teach',
#   'open',
#   'close',
#   'cabinet',
#   'door',
#   'without',
#   'touching',
#   'also',
#   'gave',
#   'magic',
#   'paintbrush',
#   'would',
#   'change',
#   'pictures',
#   'writing',
#   'paper',
#   'automatically',
#   'asked',
#   'real',
#   'things',
#   'amazed',
#   'worked',
#   'distance',
#   'remember',
#   'add',
#   'small',
#   'stars',
#   'cabinet',
#   'door',
#   "n't",
#   'thinking',
#   'anything',
#   'reproduce',
#   'time',
#   'might',
#   'problem',
#   'time',
#   'left',
#   'door',
#   'paintbrush',
#   'never',
#   'used',
#   "n't",
#   'really',
#   'like',
#   'idea',
#   'paintbrush-',
#   'would',
#   'rather',
#   'learned',
#   'close',
#   'eyes',
#   'materialize',
#   'something',
#   'anyway',
#   'soon',
#   'strange',
#   'land',
#   'looked',
#   'like',
#   'game',
#   'reality',
#   'real',
#   'life',
#   'starting',
#   'feel',
#   'completely',
#   'lucid',
#   'asked',
#   'questions',
#   'waking',
#   'life',
#   'could',
#   "n't",
#   'think',
#   'questions',
#   'ask',
#   'part',
#   'environment',
#   'underwater-',
#   "'d",
#   'open',
#   'door',
#   'swim',
#   'amazingly',
#   'water',
#   "n't",
#   'drain',
#   'room',
#   'guess',
#   "n't",
#   'amazing',
#   'time',
#   'swam',
#   'area',
#   'voice',
#   'said',
#   'intercom',
#   'point',
#   'water',
#   'feet',
#   'deep',
#   'exceedingly',
#   'low',
#   'compared',
#   'rest',
#   'ocean',
#   'good',
#   'paraphrase',
#   'look',
#   'lot',
#   'like',
#   'ocean-',
#   'lots',
#   'underwater',
#   'plants',
#   'creatures',
#   'side',
#   'saw',
#   'cousin',
#   'told',
#   'dreaming',
#   'said',
#   "'m",
#   'gave',
#   'reasons',
#   'believe',
#   'said',
#   'people',
#   'fly',
#   'yeah',
#   'said',
#   'someone',
#   'else',
#   'jumped',
#   'inches',
#   'air',
#   'trying',
#   'demonstrate',
#   'thought',
#   'might',
#   'thought',
#   'meant',
#   'airplane',
#   'something',
#   'like',
#   'said',
#   'watch',
#   'flew',
#   'feet',
#   'air',
#   'easy',
#   'came',
#   'running',
#   'things',
#   'say',
#   'reasons',
#   'could',
#   'told',
#   'think',
#   'end',
#   'realizing',
#   "'re",
#   'wake',
#   'call',
#   'patted',
#   'back',
#   'left',
#   'came',
#   'place',
#   'lot',
#   'seats',
#   'lot',
#   'people',
#   'came',
#   'really',
#   'cute',
#   'little',
#   'black',
#   'girl',
#   'might',
#   'sitting',
#   'thought',
#   'wheelchair',
#   'thought',
#   'knew',
#   'thought',
#   'kissed',
#   'cheek',
#   'asked',
#   'asked',
#   'came',
#   'back',
#   "n't",
#   'really',
#   'understand',
#   'asking',
#   'thought',
#   'maybe',
#   'mistaking',
#   'someone',
#   'else',
#   'told',
#   'see',
#   'family',
#   'friends',
#   'told',
#   "'re",
#   'one',
#   'best',
#   'friends',
#   'worldé',
#   'best',
#   'friend',
#   'promised',
#   "'d",
#   'back',
#   'spend',
#   'time',
#   'point',
#   'felt',
#   'like',
#   'knew',
#   'walking',
#   'remember',
#   'feeling',
#   'slightly',
#   'dizzy',
#   'head',
#   'everything',
#   'still',
#   'clear',
#   'could',
#   'tell',
#   'losing',
#   'consciousness',
#   'would',
#   "n't",
#   'much',
#   'seconds',
#   'sat',
#   'ground',
#   'took',
#   'hold',
#   'table',
#   'remembered',
#   'spinning',
#   'theory',
#   'spun',
#   'feet',
#   'trying',
#   'remember',
#   'woke',
#   'remember',
#   'recording',
#   'spinning',
#   'seconds',
#   "n't",
#   'feeling',
#   'dizzy',
#   "n't",
#   'remember',
#   'happened',
#   'might',
#   'woken',
#   'anyway'],
#  ['first',
#   'thing',
#   'remember',
#   'another',
#   'school',
#   'trip',
#   'bringing',
#   'bags',
#   'luggage',
#   'forgetting',
#   'hotel',
#   'also',
#   'lost',
#   'cd',
#   'thought',
#   'someone',
#   'took',
#   'threw',
#   'somewhere',
#   "n't",
#   'like',
#   'bands',
#   'listened',
#   'lot',
#   'cd',
#   'lying',
#   'around',
#   'none',
#   'mine',
#   'realized',
#   'cd',
#   'case',
#   'pocket'],
#  ['dreamed',
#   'two',
#   'old',
#   'friends-',
#   'actually',
#   'one',
#   'rhonda',
#   'thought',
#   'kim',
#   'house',
#   "n't",
#   'remember',
#   'asked',
#   'come',
#   'went',
#   'bedroom',
#   'looking',
#   'window',
#   'asked',
#   'wanted',
#   'go',
#   'walk',
#   'said',
#   'sure',
#   'asked',
#   'ask',
#   'gail',
#   'come-',
#   'kim',
#   'friend',
#   'one',
#   'really',
#   'crush',
#   'said',
#   "'d",
#   'rather',
#   "n't",
#   'call',
#   'decided',
#   'go',
#   'along',
#   'rhonda',
#   'aka',
#   'kim'],
#  ['think',
#   'woke',
#   'couch',
#   'several',
#   'people',
#   'knew',
#   'school',
#   'still',
#   'hearing',
#   'music',
#   'head',
#   'dreams',
#   "n't",
#   'completely',
#   'pleasing',
#   'talked',
#   'frank',
#   'asked',
#   'hearing',
#   'beating',
#   'trumpets',
#   'reason',
#   'thought',
#   'instrument',
#   'description-',
#   'ominous',
#   'beating',
#   'trumpets',
#   'frightened',
#   'told',
#   'yes',
#   'brought',
#   'got',
#   'terribly',
#   'afraid',
#   'curling',
#   'back',
#   'fear',
#   'way',
#   'actually',
#   'humorous',
#   'think',
#   'run',
#   'away',
#   'really',
#   'afraid',
#   'needed',
#   'point',
#   'wanted',
#   'relax',
#   'watch',
#   'tv',
#   'together',
#   "n't",
#   'want',
#   'alone',
#   'told',
#   'ok',
#   "'m",
#   'hearing',
#   'sounds',
#   'anymore',
#   'came',
#   'back',
#   'asked',
#   'music',
#   'coming',
#   'tv',
#   'everyone',
#   'else',
#   'thought',
#   'dumb',
#   'question',
#   'well',
#   'actually',
#   'everybody',
#   'laughed',
#   'thinking',
#   'joking',
#   'think',
#   'warren',
#   'responded',
#   'coming',
#   'tv',
#   'building',
#   'made',
#   'qrs',
#   'video',
#   'store',
#   'tape',
#   'rentals',
#   'less',
#   'money',
#   'buy',
#   'one',
#   'rented',
#   'video',
#   "n't",
#   'remember',
#   'one',
#   'even',
#   'knew',
#   'time',
#   'next',
#   "'m",
#   'big',
#   'old',
#   'general',
#   'surplus',
#   'store',
#   'place',
#   "n't",
#   'even',
#   'used',
#   'couple',
#   'sections',
#   'could',
#   'buy',
#   'cd',
#   "'d",
#   'wanting',
#   'replace',
#   'moxy',
#   'fruvous',
#   'cd',
#   'lost',
#   'really',
#   'thought',
#   "'d",
#   'buy',
#   'one',
#   "n't",
#   'sure',
#   'another',
#   'cd',
#   'wanted',
#   'way',
#   'back',
#   "'m",
#   'school',
#   'get',
#   'floor',
#   'space',
#   'turns',
#   'whitewater',
#   'raft',
#   'sudden',
#   'like',
#   'people',
#   'raft',
#   'made',
#   'way',
#   'much',
#   'furthermore',
#   'mostly',
#   'people',
#   'outside',
#   'school',
#   'diving',
#   'water',
#   'dived',
#   'thought',
#   'would',
#   'drown',
#   'able',
#   'get',
#   'enough',
#   'air'],
#  ["'m",
#   'outside',
#   'animal',
#   'think',
#   'fox',
#   'see',
#   'little',
#   'dog',
#   'beaten',
#   'looked',
#   'like',
#   'black',
#   'lab',
#   'fox',
#   'took',
#   'surprise',
#   'threw',
#   'nearly',
#   'dead',
#   'dog',
#   'top',
#   'taking',
#   'us',
#   'dead',
#   'ground',
#   'thought',
#   'time',
#   'dog',
#   'undoubtedly',
#   'dead',
#   'found',
#   'still',
#   'breathing',
#   'making',
#   'noise',
#   'furious',
#   'fox',
#   'poor',
#   'dog',
#   'car',
#   'trying',
#   'get',
#   'carefully',
#   'moved',
#   'dog',
#   'side',
#   'road',
#   'really',
#   "n't",
#   'think',
#   'dog',
#   'would',
#   'make',
#   'almost',
#   'hoping',
#   'someone',
#   'put',
#   'misery',
#   'really',
#   'wanted',
#   'protect',
#   'dog',
#   'hoping',
#   'might',
#   'ok.',
#   'picked',
#   'fox',
#   'gave',
#   'good',
#   'fight',
#   'claws',
#   'get',
#   'away',
#   'dog',
#   "n't",
#   'hurt',
#   'attempted',
#   'throw',
#   'fox',
#   'far',
#   'possible',
#   'assumed',
#   'fox',
#   'ok',
#   'anyway',
#   'threw',
#   'fence',
#   'might',
#   'hurt',
#   'enough',
#   "n't",
#   'go',
#   'dog',
#   'anymore',
#   'anyway',
#   'fox',
#   "n't",
#   'go',
#   'far',
#   'expected',
#   'threw',
#   'woke',
#   'immediately',
#   'throwing',
#   'fox'],
#  ['vacation',
#   'state',
#   'thought',
#   'told',
#   'girl',
#   'goes',
#   'school',
#   'friend',
#   'calls',
#   'stalker',
#   'girl',
#   'hates',
#   'world',
#   'anyway',
#   'thought',
#   'sounded',
#   'rebellious',
#   'met',
#   'nothing',
#   'like',
#   'friend',
#   'seemed',
#   'extremely',
#   'nice',
#   'different',
#   'anyone',
#   'else',
#   'knew',
#   'reason',
#   'follow',
#   'went',
#   'outside',
#   'friend',
#   'nice',
#   'guy',
#   'long',
#   'hair',
#   'told',
#   'name',
#   'could',
#   "n't",
#   'understand',
#   'saying-',
#   'sounded',
#   'like',
#   'matthew',
#   'mathais',
#   'something',
#   'beginning',
#   'm.',
#   'told',
#   'name',
#   "n't",
#   'remember',
#   'telling',
#   'hated',
#   'country',
#   'everything',
#   'consisted',
#   'told',
#   'mean',
#   'hate',
#   'country',
#   'government',
#   'love',
#   'land',
#   'mean',
#   'land',
#   'actual',
#   'land',
#   'beautiful',
#   'think',
#   'agreed',
#   'started',
#   'running',
#   'really',
#   'really',
#   'fast',
#   'sudden',
#   'saw',
#   'sign',
#   'since',
#   'vacation',
#   'state',
#   'expected',
#   'say',
#   'welcome',
#   'south',
#   'said',
#   'welcome',
#   'ohio',
#   'running',
#   'extremely',
#   'fast',
#   'hyper-speed',
#   'thought',
#   'saw',
#   'welcome',
#   'massachusetts',
#   'sign',
#   'saw',
#   'sign',
#   'said',
#   'welcome',
#   'alaska',
#   'asked',
#   'going',
#   'said',
#   "'re",
#   'going',
#   'make',
#   'clone',
#   'live',
#   'us',
#   'kansas',
#   'go',
#   'back',
#   'home',
#   'first',
#   'thought',
#   'wizard',
#   'oz',
#   'thought',
#   'vacation',
#   'state',
#   'guess',
#   'thought',
#   'kansas',
#   'said',
#   "n't",
#   'want',
#   'go',
#   'home',
#   'want',
#   'stay',
#   "n't",
#   'need',
#   'clone',
#   "'d",
#   'rather',
#   'stay',
#   'guys',
#   'wanted',
#   'part',
#   'fun',
#   'wanted',
#   'go',
#   'head',
#   'philosophy',
#   'would',
#   "n't",
#   'minded',
#   'living',
#   'forever',
#   'woke'],
#  ['first',
#   'remember',
#   'room',
#   'think',
#   'gymnasium',
#   'lot',
#   'people',
#   'remember',
#   'mall',
#   'toy',
#   'store',
#   'sort',
#   'girl',
#   'knew',
#   'sitting',
#   'something',
#   'hair',
#   'sat',
#   'threw',
#   'couple',
#   'things',
#   'table',
#   'onto',
#   'hair',
#   'realizing',
#   "n't",
#   'exactly',
#   'trying',
#   'cleaned',
#   'hair',
#   'made',
#   'sure',
#   'nothing',
#   'left',
#   'asked',
#   'wanted',
#   'get',
#   'dressed',
#   'said',
#   'wanted',
#   'wear',
#   'really',
#   'bright',
#   'colors',
#   'look',
#   'really',
#   'crazy',
#   'sort',
#   'like',
#   'motley',
#   'fool',
#   'remember',
#   'computers',
#   'people',
#   'gathered',
#   'around',
#   'girl',
#   'with-',
#   'slow',
#   'dancing',
#   'without',
#   'music',
#   'music',
#   "n't",
#   'really',
#   'needed',
#   'sat',
#   'around',
#   "n't",
#   'know',
#   'left',
#   'thought',
#   'would',
#   'gone',
#   'forever',
#   'started',
#   'dancing',
#   'someone',
#   'else',
#   'found',
#   'pretended',
#   'girl',
#   "n't",
#   'exist',
#   'told',
#   'thought',
#   'lost',
#   'happy',
#   'find',
#   'started',
#   'dancing',
#   'next',
#   'thing',
#   'know',
#   'parents',
#   'letting',
#   'brother',
#   'drive',
#   'home',
#   "n't",
#   'best',
#   'idea',
#   'first',
#   "n't",
#   'license',
#   'second',
#   'ride',
#   'stood',
#   'driver',
#   'seat',
#   'trying',
#   'look',
#   'cool',
#   'something',
#   'slowly',
#   'took',
#   'seat',
#   'belt',
#   'like',
#   'kind',
#   'dance',
#   'move',
#   'screaming',
#   'let',
#   'car',
#   'would',
#   "n't",
#   'could',
#   "n't",
#   'think',
#   'way',
#   'stop',
#   'car',
#   'without',
#   'possibility',
#   'getting',
#   'us',
#   'accident',
#   'next',
#   'thing',
#   'know',
#   "'re",
#   'home',
#   'told',
#   'mother',
#   'brother',
#   'said',
#   "'d",
#   'trouble',
#   "n't",
#   'appear',
#   'angry',
#   'saw',
#   'clarissa',
#   'girl',
#   'go',
#   'school',
#   'took',
#   'ex-girlfriend',
#   'feeling',
#   'upset',
#   'reason',
#   "n't",
#   'try',
#   'talk',
#   'felt',
#   'bad',
#   'feeling',
#   'way',
#   'wanted',
#   'know'],
#  ['walking',
#   'woods',
#   'least',
#   'edge',
#   'forest',
#   'people',
#   'girl',
#   'put',
#   'arm',
#   'around',
#   'back',
#   'said',
#   'hi-',
#   'point',
#   'knew',
#   'without',
#   'even',
#   'looking',
#   'remembered',
#   'previous',
#   'year',
#   'thought',
#   'quickly',
#   'year',
#   'went',
#   'knew',
#   "'d",
#   'met',
#   'year',
#   'realized',
#   "n't",
#   'seem',
#   'like',
#   'year',
#   'since',
#   'last',
#   'time',
#   "'d",
#   'seen',
#   'bunch',
#   'people',
#   'going',
#   'whitewater',
#   'rafting',
#   'one',
#   'them-',
#   'girl',
#   'told',
#   'something',
#   'better',
#   'follow',
#   'started',
#   'running',
#   'followed',
#   'went',
#   'rocks',
#   'next',
#   'river',
#   'soon',
#   'saw',
#   'whitewater',
#   'people',
#   'water',
#   'catching',
#   'started',
#   'running-',
#   'afraid',
#   "'d",
#   'us',
#   'think',
#   'thought',
#   'asian',
#   'communist',
#   'country',
#   'something',
#   'land',
#   'reminded',
#   'asia',
#   'trying',
#   'force',
#   'us',
#   'go',
#   'whitewater',
#   'rafting',
#   'afraid',
#   "'d",
#   'catch',
#   'us',
#   'ran',
#   'away',
#   'rafting',
#   'group',
#   'think',
#   'girl',
#   'either',
#   'disappeared',
#   'turned',
#   'boy',
#   'anyway',
#   'think',
#   'showed',
#   'book',
#   'written',
#   'former',
#   'prep',
#   'academy',
#   'student',
#   'started',
#   'reading',
#   'impressed',
#   'wanted',
#   'show',
#   'everyone',
#   'great',
#   'book',
#   'felt',
#   'like',
#   'movie',
#   'taped',
#   'prep',
#   'academy',
#   'remember',
#   'taping',
#   'certain',
#   'things',
#   'prep',
#   'academy-',
#   'example',
#   'water',
#   'splashing',
#   'water',
#   'saying',
#   'prep',
#   'academy',
#   'laughing'],
#  ['first',
#   'remember',
#   'wanting',
#   'dress',
#   'girl',
#   'reason',
#   'putting',
#   'makeup',
#   'eyeshadow',
#   'weird',
#   'stuff',
#   'hair',
#   'actually',
#   'starting',
#   'look',
#   'like',
#   'girl',
#   'think',
#   'actually',
#   'looking',
#   'mirror',
#   'remember',
#   'guy',
#   'smoking',
#   'cigarette',
#   'house',
#   'mother',
#   'friend',
#   'getting',
#   'really',
#   'mad',
#   'mother',
#   'letting',
#   'smoke',
#   'house',
#   'started',
#   'singing',
#   'french-',
#   'incomprehensible',
#   'french-',
#   'recognized',
#   'voulez',
#   'something',
#   'even',
#   'barely',
#   'remember',
#   'guy',
#   "n't",
#   'know',
#   'thing',
#   'trying',
#   'look',
#   'like',
#   'girl',
#   'walking',
#   'beach',
#   'tide',
#   'high'],
#  ['remember',
#   'cat-',
#   "n't",
#   'know',
#   'got',
#   'actually',
#   'little',
#   'kitten',
#   'holding',
#   'loved',
#   'cutest',
#   'kitten-',
#   'reminded',
#   'grandfather',
#   'cat',
#   'doc',
#   'year',
#   'ago',
#   'took',
#   'outside',
#   'holding',
#   'petting',
#   'time',
#   'remember',
#   'wanting',
#   'kitten',
#   'grow',
#   'up-',
#   'thought',
#   'noticed',
#   'personality',
#   'change',
#   "n't",
#   'want',
#   'hold',
#   'time',
#   'anymore',
#   'still',
#   'acting',
#   'like',
#   'kitten',
#   'anyway',
#   'thinking',
#   "n't",
#   'feel',
#   'bad',
#   'kitten',
#   'growing',
#   'well',
#   'get',
#   'another',
#   'kitten',
#   'someday'],
#  ['somebody',
#   'baby',
#   'kitchen',
#   'really',
#   'excited',
#   'tried',
#   'teach',
#   'become',
#   'self-conscious-',
#   'touching',
#   'nose',
#   'hoping',
#   "'d",
#   'example',
#   'imagining',
#   'smart',
#   "'d",
#   'got',
#   'older',
#   'remember',
#   'clarissa',
#   'yelling',
#   'getting',
#   'work',
#   'done',
#   'project',
#   'supposedly',
#   'physics',
#   'jamie',
#   'standing',
#   'innocent',
#   'looking',
#   'brother',
#   'trying',
#   'profit',
#   'naivety',
#   'certain',
#   'store',
#   'clerks',
#   'complaining',
#   'mother',
#   'trying',
#   'get',
#   'stop',
#   'worrying',
#   'problem',
#   'computer',
#   'recognized',
#   'big',
#   'deal',
#   'jamie',
#   'still',
#   'standing',
#   'way',
#   'turned',
#   'computer',
#   'complaining',
#   'would',
#   "n't",
#   'able',
#   'get',
#   'weather',
#   'tried',
#   'explain',
#   'lost',
#   'street',
#   'map',
#   "'d",
#   'still',
#   'check',
#   'internet',
#   'map',
#   'anyway',
#   "'m",
#   'somewhere',
#   'else',
#   'hear',
#   'supposedly',
#   'old',
#   'barenaked',
#   'ladies',
#   'song',
#   "'ve",
#   'never',
#   'heard',
#   'anyway',
#   'wanted',
#   'go',
#   'walk',
#   'jamie',
#   'hang',
#   'tell',
#   'something',
#   'never',
#   'got',
#   'chance'],
#  ["'m",
#   'library',
#   'looks',
#   'much',
#   'like',
#   'plainview',
#   'high',
#   'school',
#   'library',
#   "'m",
#   'looking',
#   'box',
#   'old',
#   'books',
#   'subjects',
#   'like',
#   'astral',
#   'projection',
#   'witchcraft',
#   'spotted',
#   'names',
#   'relatives',
#   'jamie',
#   'one',
#   'witchcraft',
#   'books',
#   'remember',
#   'first',
#   'name',
#   'jenny',
#   'someone',
#   'else',
#   'named',
#   's.',
#   'spinney',
#   "'m",
#   'sure',
#   'significance',
#   'names',
#   'actually',
#   'since',
#   'remember',
#   'thought',
#   "'d",
#   'include',
#   'remember',
#   'going',
#   'old',
#   'female',
#   'teacher',
#   'outdoor',
#   'sort',
#   'library',
#   'place',
#   'started',
#   'asking',
#   'knew',
#   'anything',
#   'said',
#   'long',
#   'family',
#   'history',
#   'witchcraft',
#   'knew',
#   'well',
#   'found',
#   'jenny',
#   's.',
#   'lot',
#   'like',
#   'jamie',
#   'many',
#   'ways',
#   'one',
#   'books',
#   'whole',
#   'thing',
#   'almost',
#   'like',
#   'mystery',
#   'figuring',
#   'found',
#   'jamie',
#   'lying',
#   'asked',
#   'get',
#   'said',
#   "'d",
#   'sunburnt',
#   'something',
#   'like',
#   'still',
#   'tried',
#   'persuade',
#   'get',
#   'found',
#   'researching',
#   'family',
#   'history',
#   'think',
#   'felt',
#   'betraying',
#   'remember',
#   'guinea',
#   'pig',
#   'little',
#   'creature',
#   'hand',
#   'people',
#   'told',
#   'go',
#   'lake',
#   'soon',
#   'realized',
#   "n't",
#   'best',
#   'idea-',
#   'people',
#   'throwing',
#   'rocks',
#   'people',
#   'knew',
#   "n't",
#   'trust',
#   'hard',
#   'get',
#   'away',
#   'lake',
#   'without',
#   'falling',
#   'hoping',
#   'little',
#   'animal',
#   'would',
#   "n't",
#   'hurt',
#   'animal',
#   'ended',
#   'fine',
#   'either',
#   'spanish',
#   'class',
#   'history',
#   'class',
#   'teacher',
#   'sort',
#   'mix',
#   'dell',
#   'lamacchia',
#   'first',
#   'like',
#   'dell',
#   'gradually',
#   'becoming',
#   'like',
#   'mr.',
#   'grant',
#   'guess',
#   "'d",
#   'chosen',
#   'final',
#   'spanish',
#   'exam',
#   "n't",
#   'think',
#   'well',
#   'first',
#   'time',
#   'even',
#   'worse',
#   'second',
#   'time',
#   'however',
#   'playing',
#   'something',
#   'board',
#   'something',
#   'like',
#   'wheel',
#   'history',
#   'game',
#   'used',
#   'play',
#   'mr.',
#   'grant',
#   'class',
#   'quite',
#   'remember',
#   'playing',
#   'hide',
#   'go',
#   'seek',
#   'everyone',
#   'going',
#   'around',
#   'hiding',
#   'something',
#   'went',
#   'small',
#   'room',
#   'found',
#   'jamie',
#   'could',
#   "n't",
#   'describe',
#   'knew',
#   'looked',
#   'different',
#   'kept',
#   'telling',
#   'friend',
#   'listen'],
#  ["'re",
#   'europe',
#   "'m",
#   'tired',
#   'mr.',
#   'dell',
#   'reading',
#   'plan',
#   'everything',
#   "'re",
#   'going',
#   'day',
#   "'re",
#   'leaving',
#   'one',
#   'hotel',
#   'go',
#   'another',
#   'think',
#   'ok',
#   'leave',
#   'luggage',
#   'reason',
#   'next',
#   'thing',
#   'know',
#   "'re",
#   'think',
#   'bus',
#   'back',
#   'tell',
#   'left',
#   'cats',
#   'hotel',
#   'think',
#   'mr.',
#   'dell',
#   'gave',
#   'tied',
#   'could',
#   "n't",
#   'go',
#   'anywhere',
#   'like',
#   'one',
#   'legs',
#   'attached',
#   'face',
#   'rope',
#   'looked',
#   'uncomfortable',
#   'felt',
#   'bad',
#   'think',
#   'put',
#   'bathtub',
#   'mr.',
#   'rosetti',
#   'comes',
#   'walking',
#   'sudden',
#   'cats',
#   'little',
#   'insects',
#   'one',
#   'small',
#   'pig',
#   "n't",
#   'think',
#   'anything',
#   'change',
#   'mr.',
#   'rosetti',
#   'walks',
#   'bathroom',
#   'sees',
#   'insects',
#   'know',
#   'exactly',
#   'shout',
#   'late',
#   'start',
#   'screaming',
#   'crying',
#   'hysterically',
#   'killed',
#   'cat',
#   "n't",
#   'understand',
#   'cat',
#   "'m",
#   'crying',
#   'walking',
#   'toward',
#   'front',
#   'bus',
#   'telling',
#   'everybody',
#   'happened',
#   'monica',
#   'hugs',
#   'suddenly',
#   'feel',
#   'better',
#   'even',
#   'sure',
#   'remember',
#   'happened',
#   'say',
#   'comfort'],
#  ['prep',
#   'academy',
#   'group',
#   'project-',
#   'building',
#   'mini-vehicle',
#   'farm',
#   'vehicle',
#   'maybe',
#   'sort',
#   'sudden',
#   'rest',
#   'project',
#   'crashes',
#   'floor',
#   'look',
#   'see',
#   'still',
#   'ok',
#   'see',
#   'everything',
#   'broken',
#   'start',
#   'laughing',
#   'unable',
#   'stop',
#   'woke',
#   'times',
#   'least',
#   'false',
#   'awakenings',
#   'confused',
#   'room',
#   "n't",
#   'completely',
#   'look',
#   'like',
#   'bedroom-',
#   'really',
#   'could',
#   'real',
#   'awakening',
#   'anyway',
#   'also',
#   'remember',
#   'almost',
#   'definitely',
#   'false',
#   'awakening-',
#   'trying',
#   'break',
#   'bedroom',
#   'window',
#   'telekinesis',
#   'sudden',
#   'wake',
#   "'m",
#   'looking',
#   'real',
#   'window'],
#  ['remember',
#   'violent',
#   'someone',
#   'trying',
#   'hurt',
#   'janice',
#   'knife',
#   'similar',
#   'device',
#   "n't",
#   'remember',
#   'much',
#   'next',
#   'thing',
#   'know',
#   'guy',
#   'across',
#   'street',
#   'house',
#   'aiming',
#   'gun',
#   'get',
#   'behind',
#   'someone',
#   'else',
#   'try',
#   'escape',
#   'ca',
#   "n't",
#   'move',
#   'fast',
#   'think',
#   'wake',
#   'fall',
#   'back',
#   'asleep',
#   'time',
#   "'ve",
#   'found',
#   'gun',
#   'somewhere',
#   'pull',
#   'safety',
#   'push',
#   'trigger',
#   'shoot',
#   'try',
#   'figure',
#   'put',
#   'safety',
#   'back',
#   "'m",
#   'afraid',
#   "'ll",
#   'shoot',
#   'somebody',
#   'almost',
#   'pull',
#   'trigger',
#   'couple',
#   'times',
#   'go',
#   'outside',
#   'cats',
#   'there-',
#   'accidentally',
#   'aim',
#   'barrel',
#   'want',
#   'shoot',
#   'gun',
#   'somewhere',
#   'safe',
#   "'m",
#   'heading',
#   'toward',
#   'shed',
#   'gun',
#   'starts',
#   'shake',
#   'bit',
#   'extremely',
#   'hot',
#   'liquid',
#   'comes',
#   'gun',
#   'hurts-',
#   'feel',
#   'punishment',
#   'god',
#   'something-',
#   'think',
#   'hear',
#   'voice',
#   'god',
#   'saying',
#   'try',
#   'shoot',
#   'hand',
#   'numbing',
#   'feel',
#   'gun',
#   'blow',
#   'throw',
#   'blows',
#   'run',
#   'inside',
#   'house',
#   'sounds',
#   'looks',
#   'like',
#   'series',
#   'bombs',
#   'going',
#   "'m",
#   'afraid',
#   'starting',
#   'bomb',
#   'right',
#   'next',
#   'house',
#   'penetrating',
#   'house',
#   'start',
#   'fire',
#   "'m",
#   'right',
#   'near',
#   'phone',
#   'call',
#   'wake',
#   'fall',
#   'asleep',
#   "'m",
#   'europe',
#   'again-',
#   "n't",
#   'remember',
#   'exactly',
#   'going',
#   'except',
#   'group',
#   'us',
#   'traveling',
#   'europe',
#   'remember',
#   'france',
#   'possibly',
#   'italy',
#   'germany',
#   "'re",
#   'lot',
#   'walking',
#   'mostly',
#   'fields',
#   'forest',
#   "n't",
#   'remember',
#   'walking',
#   'cities',
#   'areas',
#   'civilization',
#   'adventure',
#   'offer',
#   'carry',
#   'tired',
#   'girl',
#   'back',
#   "n't",
#   'really',
#   'take',
#   'much',
#   'effort',
#   'realized',
#   'maybe',
#   'wanted',
#   'come',
#   'walk',
#   'bit',
#   'let',
#   "n't",
#   'remember',
#   'exactly',
#   'was-',
#   'could',
#   'bernice',
#   'monica',
#   'janice-',
#   'likely',
#   'bernice',
#   'anyway',
#   'remember',
#   'restaurant',
#   'trying',
#   'order',
#   'food',
#   'find',
#   'italian',
#   'lire',
#   'currencies',
#   'need',
#   'french',
#   'francs',
#   "'m",
#   'still',
#   'walking',
#   'almost',
#   'home',
#   "'m",
#   'house',
#   'far',
#   'house',
#   'guy',
#   'begging',
#   'money',
#   'outside',
#   "n't",
#   'remember',
#   'exactly',
#   'happens',
#   'give',
#   'money',
#   'go',
#   'inside',
#   'house',
#   'reason',
#   'threatens',
#   'shoot',
#   "'m",
#   'running',
#   'really',
#   'fast'],
#  ['sat',
#   'scores',
#   'coming',
#   'go',
#   'principal',
#   'office',
#   'pick',
#   'results',
#   'get',
#   'package',
#   'ets',
#   'contains',
#   'maybe',
#   'different',
#   'snacks',
#   'candies',
#   "'m",
#   'expecting',
#   'sat',
#   'scores',
#   "'m",
#   'disappointed'],
#  ['first',
#   'thing',
#   'remember',
#   'bus',
#   "'re",
#   'driving',
#   'eastern',
#   'state',
#   "'re",
#   'north',
#   'carolina',
#   'think',
#   'like',
#   'hour',
#   'drive',
#   'something',
#   'like',
#   'that-',
#   'considered',
#   'considerably',
#   'long',
#   'although',
#   'nc',
#   'know',
#   'quickly',
#   'hours',
#   'disappointed',
#   'day',
#   'would',
#   'almost',
#   'time',
#   'got',
#   'back',
#   'mr.',
#   'dell',
#   'asked',
#   'give',
#   'back',
#   'frogs',
#   'legs',
#   'gave',
#   'earlier',
#   'said',
#   "'m",
#   'concerned',
#   'legs',
#   'container',
#   'remember',
#   'big',
#   'room',
#   'part',
#   'bus',
#   'could',
#   'hear',
#   'start',
#   'moving',
#   'along',
#   'bus',
#   'anyway',
#   'bedroom',
#   'lot',
#   'us',
#   'going',
#   'sleep',
#   'remember',
#   'thought',
#   'airport',
#   "'m",
#   'grandparents',
#   'one',
#   'looks',
#   'like',
#   'grandmother',
#   'lady',
#   'lot',
#   'bigger',
#   'looked',
#   'masculine',
#   "n't",
#   'tried',
#   'convince',
#   'really',
#   'though',
#   'soon',
#   'fell',
#   'threw',
#   'ground',
#   'yelled',
#   'something',
#   'remember',
#   'amusement',
#   'park',
#   'asked',
#   'almost',
#   'every',
#   'single',
#   'girl',
#   'place',
#   'dance',
#   'seemed',
#   'crazy',
#   'boy',
#   'danced',
#   'moved',
#   'around',
#   'like',
#   'crazy',
#   'even',
#   'though',
#   'ca',
#   "n't",
#   'dance',
#   "n't",
#   'matter-',
#   'still',
#   'fun',
#   'one',
#   'house',
#   'right',
#   'nearby',
#   'looked',
#   'went',
#   'house',
#   'bring',
#   'cat',
#   'back',
#   'something',
#   'like',
#   'getting',
#   'sort',
#   'bored-',
#   'wanted',
#   'dance',
#   "'m",
#   'running',
#   'around',
#   'realizing',
#   'might',
#   "'m",
#   'supposed',
#   'mrs.',
#   'lear',
#   'tells',
#   'group',
#   'right',
#   'inside',
#   'ride',
#   "'m",
#   'inside',
#   'building',
#   'see',
#   'somebody',
#   'say',
#   'hey',
#   'laura',
#   'everybody',
#   'knew',
#   'going',
#   'ask',
#   'running',
#   'fast',
#   'never',
#   'heard',
#   'mr.',
#   'dell',
#   'within',
#   'incredibly',
#   'old',
#   'building',
#   'built',
#   'mr.',
#   'dell',
#   'museum',
#   'thought',
#   'saw',
#   'blocking',
#   'doors',
#   'rooms',
#   'except',
#   'rooms',
#   'personal',
#   'museum',
#   'told',
#   'student',
#   'hurry',
#   'dell',
#   'lock',
#   'doors',
#   "n't",
#   'know',
#   'actually',
#   'actually',
#   'decided',
#   'wanted',
#   'see',
#   'dell',
#   'museum',
#   'mr.',
#   'dell',
#   'somehow',
#   'gotten',
#   'behind',
#   'steep',
#   'stairs',
#   'sort',
#   'realize',
#   "'m",
#   'dreaming',
#   'see',
#   'would',
#   'impossible',
#   'climb',
#   'stairs',
#   'real',
#   'life',
#   'idea',
#   "'m",
#   'dreaming',
#   'wonder',
#   'brice',
#   'remember',
#   'asking',
#   'girls',
# ...
#   'emotion',
#   'spirit',
#   'later',
#   'clad',
#   'shirt',
#   'looking',
#   'trousers'],
#  ['hospital',
#   'patient',
#   'wandered',
#   'away',
#   'stern-looking',
#   'attendant',
#   'brought',
#   'back',
#   'order',
#   'cure',
#   'doctor',
#   'transferred',
#   'women',
#   'ward'],
#  ['taking',
#   'bath',
#   'clothes',
#   'tub',
#   'tried',
#   'hurry',
#   'patient',
#   'ward',
#   'appeared',
#   'waiting',
#   'bathe'],
#  ['came',
#   'piece',
#   'machinery',
#   'asked',
#   'man',
#   'charge',
#   'could',
#   'something',
#   'refused',
#   'let',
#   'later',
#   'saw',
#   'woman',
#   'rusty',
#   'colored',
#   'fur',
#   'coat',
#   'scrubbing',
#   'floor',
#   'vigorously'],
#  ['beautiful',
#   'large',
#   'house',
#   'young',
#   'lady',
#   'took',
#   'inside',
#   'high',
#   'ceilings',
#   'arches',
#   'balconies',
#   'walls',
#   'painted',
#   'pastel',
#   'colors',
#   'first',
#   'time',
#   'remember',
#   'color'],
#  ['mother', 'playing', 'catch', 'gym', 'good'],
#  ['locked',
#   'somewhere',
#   'released',
#   'went',
#   'secluded',
#   'place',
#   'urinated',
#   'interrupted',
#   'times',
#   'passersby'],
#  ['mass',
#   'auditorium',
#   'hospital',
#   'patients',
#   'changed',
#   'seats',
#   'went',
#   'outside',
#   'started',
#   'pick',
#   'flower',
#   'stopped',
#   'hand',
#   'looked',
#   'saw',
#   'sister',
#   'hand',
#   'said',
#   "n't",
#   'pick',
#   'flower',
#   'may',
#   'break',
#   'bulb',
#   'underneath',
#   'decided',
#   'pick',
#   'carefully',
#   'bulb',
#   'broke',
#   'anyway',
#   'sister',
#   'sad',
#   'started',
#   'cry',
#   'said',
#   'right',
#   'best',
#   'could',
#   'held',
#   'hands',
#   'tried',
#   'smile'],
#  ['hysterical',
#   'woman',
#   'pulling',
#   'top',
#   'dress',
#   'exposing',
#   'body',
#   'later',
#   'saw',
#   'man',
#   'woman',
#   'burying',
#   'man',
#   'head',
#   'lot',
#   'man',
#   'turban',
#   'head',
#   'drove',
#   'tried',
#   'get',
#   'license',
#   'number',
#   'man',
#   'saw',
#   'later',
#   'going',
#   'building',
#   'man',
#   'appeared',
#   'behind',
#   'began',
#   'chasing',
#   'shouted',
#   'police',
#   'kept',
#   'following'],
#  ['cemetery', 'drinking', 'felt', 'though', 'drunk'],
#  ['younger',
#   'built',
#   'wheelbarrow',
#   'carry',
#   'ice',
#   'packed',
#   'bags',
#   'know',
#   'deliver',
#   'ice',
#   'saw',
#   'truck',
#   'parked',
#   'front',
#   'laundry',
#   'mother',
#   'came',
#   'gave',
#   'coin',
#   'telephone',
#   'ice',
#   'left',
#   'went',
#   'telephone'],
#  ['driving',
#   'car',
#   'streets',
#   'looking',
#   'building',
#   'later',
#   'outside',
#   'restaurant',
#   'woman',
#   'inside',
#   'talking',
#   'robbery',
#   'taken',
#   'place',
#   'police',
#   'coming'],
#  ['met',
#   'little',
#   'girl',
#   'became',
#   'companionable',
#   'felt',
#   'romantic',
#   'attachment'],
#  ['someone',
#   'assaulted',
#   'little',
#   'girl',
#   'sexually',
#   'sister',
#   'thought',
#   'done',
#   'told',
#   'first',
#   'doubted',
#   'said',
#   'believed',
#   'laughed',
#   'held',
#   'hands'],
#  ['boy',
#   'something',
#   'happened',
#   'upset',
#   'later',
#   'saw',
#   'intestines',
#   'exposed',
#   'dry',
#   'small',
#   'piece',
#   'hung',
#   'loose',
#   'touched',
#   'fell',
#   'worried',
#   'injured',
#   'boy',
#   'causing',
#   'piece',
#   'fall'],
#  ['loading',
#   'things',
#   'wagon',
#   'military',
#   'policemen',
#   'thought',
#   'something',
#   'suspicious'],
#  ['sliding', 'hill', 'slid', 'pond', 'fishes', 'water'],
#  ['fastened',
#   'bed',
#   'board',
#   'across',
#   'legs',
#   'hands',
#   'tied',
#   'sides',
#   'bed',
#   'imagined',
#   'woman',
#   'tied',
#   'bedpan',
#   'intended',
#   'keep',
#   'tied',
#   'long',
#   'time',
#   'time',
#   'imagined',
#   'victim'],
#  ['repairing',
#   'something',
#   'later',
#   'going',
#   'printing',
#   'plant',
#   'apply',
#   'work',
#   'man',
#   'railroad',
#   'station',
#   'looked',
#   'like',
#   'experienced',
#   'traveling',
#   'missed',
#   'train',
#   'could',
#   "n't",
#   'find',
#   'platform',
#   'walked',
#   'tracks',
#   'passed',
#   'lizards',
#   'eating',
#   'one',
#   'looked',
#   'though',
#   'eating',
#   'another',
#   'lizard',
#   'actually',
#   'eating',
#   'came',
#   'plant',
#   "n't",
#   'apply',
#   'bindery',
#   'help',
#   'wanted',
#   'mother',
#   'working',
#   'clad',
#   'trousers',
#   'undershirt',
#   'passed',
#   'sandlot',
#   'became',
#   'nostalgic',
#   'reminded',
#   'event',
#   'past'],
#  ['getting',
#   'dressed',
#   'dance',
#   'three',
#   'hours',
#   'passed',
#   'worried',
#   'late',
#   'dance'],
#  ['put',
#   'piece',
#   'feces',
#   'water',
#   'came',
#   'alive',
#   'started',
#   'move',
#   'away',
#   'saw',
#   'little',
#   'boy',
#   'repressed',
#   'erotic',
#   'desire',
#   'bought',
#   'gallon',
#   'milk',
#   'waiting',
#   'another',
#   'one',
#   'ordered'],
#  ['house',
#   'built',
#   'men',
#   'sneaking',
#   'cable',
#   'hiding',
#   'building',
#   'evading',
#   'law',
#   'pretended',
#   'workers',
#   'patient',
#   'ward',
#   'named',
#   'perez',
#   'came',
#   'building',
#   'old',
#   'man',
#   'wanted',
#   'abduct',
#   'forcing',
#   'truck',
#   'fought',
#   'patient',
#   'overcome',
#   'driven',
#   'truck'],
#  ['forced',
#   'walk',
#   'ahead',
#   'policemen',
#   'wearing',
#   'earphones',
#   'found',
#   'radio',
#   'equipment',
#   'patient',
#   'ward',
#   'named',
#   'ward',
#   'said',
#   'could',
#   "n't",
#   'arrest',
#   'us',
#   'radio',
#   'short',
#   'wave'],
#  ['girl',
#   'wearing',
#   'panty',
#   'covered',
#   'sides',
#   'hips',
#   'put',
#   'another',
#   'one',
#   'covered',
#   'crotch',
#   'buttocks'],
#  ['store',
#   'saleslady',
#   'asked',
#   'wanted',
#   'pay',
#   'woman',
#   'sleep',
#   'said',
#   'afraid',
#   'contracting',
#   'venereal',
#   'disease',
#   'woman',
#   'began',
#   'speaking',
#   'spanish'],
#  ['working',
#   'printing',
#   'plant',
#   'woman',
#   'teaching',
#   'operate',
#   'printing',
#   'press',
#   'later',
#   'met',
#   'little',
#   'girls',
#   'park'],
#  ['train',
#   'get',
#   'information',
#   'policemen',
#   'looking',
#   'something',
#   'smuggled',
#   'left',
#   'train',
#   'saw',
#   'man',
#   'get',
#   'arrested',
#   'building',
#   'tried',
#   'get',
#   'smuggled',
#   'goods',
#   'inside',
#   'later',
#   'elevator',
#   'conveyor',
#   'belt',
#   'steel',
#   'structure',
#   'resembling',
#   'tower'],
#  ['hospital',
#   'patient',
#   'going',
#   'others',
#   'dining',
#   'hall',
#   'passed',
#   'women',
#   'ward',
#   'nude',
#   'one',
#   'smiled',
#   'noticed',
#   'penis',
#   'protruding',
#   'inside',
#   'organ',
#   'reached',
#   'dining',
#   'hall',
#   'noticed',
#   'patients',
#   'unclad',
#   'many',
#   'missing',
#   'told',
#   'eating',
#   'somewhere',
#   'else',
#   'patient',
#   'ward',
#   'named',
#   'buckley',
#   'sitting',
#   'next',
#   'special',
#   'dinner',
#   'imported',
#   'china',
#   'tables',
#   'men',
#   'platform'],
#  ['yard',
#   'playing',
#   'softball',
#   'good',
#   'cave',
#   'yard',
#   'patient',
#   'ward',
#   'named',
#   'farell',
#   'dog',
#   'went',
#   'mr.',
#   'farell',
#   'annoyed'],
#  ['searching', 'strange', 'streets', 'looking', 'certain', 'neighborhood'],
#  ['house',
#   'slim',
#   'dark-skinned',
#   'brunette',
#   'asked',
#   'would',
#   'sex',
#   'relations',
#   'agreed',
#   'watch',
#   'man',
#   'came',
#   'house',
#   'separate',
#   'tall',
#   'years',
#   'old',
#   'later',
#   'playing',
#   'word',
#   'game',
#   'brunette',
#   'word',
#   'mouse',
#   'used',
#   'game',
#   'giggled',
#   'little',
#   'winked'],
#  ['school',
#   'room',
#   'desk',
#   'put',
#   'basket',
#   'floor',
#   'boy',
#   'uncooperative',
#   'student'],
#  ['veterans',
#   'administration',
#   'office',
#   'waiting',
#   'interview',
#   'building',
#   'remodeled',
#   'since',
#   'last',
#   'visit',
#   'old',
#   'windows',
#   'felt',
#   'cold',
#   'draft',
#   'air',
#   'others',
#   'hospital'],
#  ['mopping',
#   'floor',
#   'clad',
#   'apron',
#   'worried',
#   'back',
#   'body',
#   'exposed',
#   'pool',
#   'next',
#   'room',
#   'went',
#   'inside',
#   'go',
#   'swimming',
#   'pool',
#   'drained'],
#  ['served', 'ice', 'cream', 'patient', 'named', 'plante'],
#  ['looking',
#   'calendars',
#   'store',
#   'counter',
#   'picked',
#   'catholic',
#   'calendar',
#   'saw',
#   'envelope',
#   'sealed',
#   'thought',
#   'might',
#   'better',
#   'calendar',
#   'something',
#   'else',
#   'inside',
#   'felt',
#   'guilty',
#   'breaking',
#   'seal',
#   'tried',
#   'reseal',
#   'wax',
#   'seal',
#   'round',
#   'inch',
#   'diameter'],
#  ['mother', 'sister', 'car', 'sinking', 'mud', 'get', 'car'],
#  ['went',
#   'chair',
#   'someone',
#   'standing',
#   'get',
#   'pajamas',
#   'elastic',
#   'tight',
#   'around',
#   'waist',
#   'stretched',
#   'mother',
#   'left'],
#  ['putting',
#   'things',
#   'away',
#   'shelves',
#   'everything',
#   'put',
#   'certain',
#   'place'],
#  ['went',
#   'hallway',
#   'go',
#   'shower',
#   'room',
#   'surprised',
#   'see',
#   'woman',
#   'showering',
#   'surprised',
#   'annoyed',
#   'seeing',
#   'went',
#   'back',
#   'hall',
#   'room'],
#  ['received',
#   'memo',
#   'pad',
#   'hung',
#   'wall',
#   'tube',
#   'red',
#   'ink',
#   'refilling',
#   'pen',
#   'tried',
#   'write',
#   'something',
#   'interrupted',
#   'officer',
#   'mr.',
#   'thom',
#   'former',
#   'ward',
#   'second',
#   'time',
#   'recall',
#   'seeing',
#   'color'],
#  ['theater',
#   'watching',
#   'movie',
#   'man',
#   'traveling',
#   'section',
#   'city',
#   'woman',
#   'sat',
#   'next',
#   'slender',
#   'attractive',
#   'seemed',
#   'know',
#   'go',
#   'rest',
#   'room',
#   'urinals',
#   'awkward',
#   'place',
#   'returned',
#   'man',
#   'movie',
#   'found',
#   'place',
#   'looking',
#   'movie',
#   'ending'],
#  ['lunch',
#   'counter',
#   'little',
#   'later',
#   'several',
#   'seats',
#   'missing',
#   'bar-like',
#   'footrest',
#   'replaced'],
#  ['hospital',
#   'patient',
#   'church',
#   'patients',
#   'woman',
#   'patient',
#   'stood',
#   'men',
#   'seated',
#   'slender',
#   'looked',
#   'later',
#   'walking',
#   'church',
#   'mass',
#   'wearing',
#   'suit',
#   'found',
#   'could',
#   'float',
#   'horizontally',
#   'feet',
#   'ground',
#   'traveled',
#   'miles',
#   'hour',
#   'eluding',
#   'attendants',
#   'came',
#   'motor-powered',
#   'paper',
#   'cutter',
#   'someone',
#   'said',
#   'killing',
#   'fish',
#   'fish',
#   'would',
#   'trip',
#   'switch',
#   'releasing',
#   'blade',
#   'came',
#   'upon',
#   'fish',
#   'needed',
#   'glycerin',
#   'went',
#   'get',
#   'tried',
#   'float',
#   'could',
#   "n't",
#   'noticed',
#   "n't",
#   'wearing',
#   'suit',
#   'coat',
#   'assumed',
#   'needed',
#   'coat',
#   'order',
#   'float',
#   "n't",
#   'recall',
#   'took',
#   'wearing',
#   'floating'],
#  ['train',
#   'passed',
#   'children',
#   'playing',
#   'behind',
#   'house',
#   'near',
#   'wood',
#   'first',
#   'seemed',
#   'alone',
#   'reasoned',
#   'parents',
#   'probably',
#   'nearby',
#   'train',
#   'came',
#   'station',
#   'saw',
#   'sister',
#   'waved',
#   'later',
#   'riding',
#   'ferris',
#   'wheel'],
#  ['writing', 'words', 'insert', 'letter', 'q'],
#  ['carpenter',
#   'shop',
#   'three',
#   'men',
#   'asleep',
#   'beds',
#   'enclosure',
#   '5-foot',
#   'wall',
#   'around',
#   'nurses',
#   'came',
#   'awakened',
#   'worked',
#   'shop',
#   'us'],
#  ['someone', 'combing', 'cutting', 'hair', 'parted', 'center'],
#  ['bus',
#   'men',
#   'saw',
#   'woman',
#   'elevated',
#   'road',
#   'thought',
#   'mother',
#   'first',
#   'later',
#   'bus',
#   'mother',
#   'sister',
#   'driver',
#   'left',
#   'emergency',
#   'door',
#   'partly',
#   'open',
#   'worried',
#   'could',
#   'fall',
#   'bus',
#   'later',
#   'walking',
#   'mother',
#   'appeared',
#   'taller',
#   'soiled',
#   'something',
#   'urine'],
#  ['mopping', 'floor', 'straight', 'lines', 'talking', 'urinating'],
#  ['took',
#   'taxi',
#   'avoid',
#   'police',
#   'patient',
#   'named',
#   'young',
#   'lost',
#   'weight'],
#  ['sprinkling',
#   'hose',
#   'street',
#   'saw',
#   'stick',
#   'seemed',
#   'leaf',
#   'growing',
#   'boy',
#   'told',
#   'leaf',
#   'came',
#   'vine',
#   'hanging',
#   'put',
#   'vine',
#   'stick'],
#  ['consoling', 'people', 'told', 'must', 'faith'],
#  ['italian',
#   'counterfeiter',
#   'decided',
#   'go',
#   'straight',
#   'burned',
#   'plates',
#   'melted'],
#  ['went',
#   'see',
#   'doctor',
#   'getting',
#   'released',
#   'hospital',
#   'stood',
#   'behind',
#   'looked',
#   'like',
#   'bank',
#   'teller',
#   'window',
#   'soft-spoken',
#   'seemed',
#   'busy',
#   'later',
#   'posed',
#   'photograph',
#   'told',
#   'sister',
#   'sprinkling',
#   'hose',
#   'paint',
#   'index',
#   'finger',
#   'mother',
#   'tried',
#   'rub',
#   'told',
#   'sister',
#   'careful'],
#  ['lying',
#   'back',
#   'holding',
#   'large',
#   'cat',
#   'later',
#   'sitting',
#   'desk',
#   'like',
#   'ones',
#   'went',
#   'school',
#   'desk',
#   'small',
#   'taking',
#   'word',
#   'test',
#   'little',
#   'later',
#   'strange',
#   'dormitory',
#   'patient',
#   'named',
#   'katz',
#   'sleeping',
#   'next',
#   'returned',
#   'pencil',
#   'borrowed',
#   'moved',
#   'someone',
#   'else',
#   'bed',
#   'worried',
#   'occupant',
#   'returning',
#   'noticed',
#   'coincidence',
#   'cat',
#   'patient',
#   'named',
#   'katz',
#   'yesterday',
#   'petted',
#   'stray',
#   'cat',
#   'yard',
#   'intellectual',
#   'discussions',
#   'mr',
#   'katz'],
#  ['swelling',
#   'two',
#   'fingers',
#   'later',
#   'working',
#   'printing',
#   'presses',
#   'flywheel',
#   'came',
#   'press',
#   'running',
#   'sailed',
#   'air',
#   'presses'],
#  ['moving',
#   'room',
#   'mother',
#   'sister',
#   'left',
#   'remembered',
#   'shirt',
#   'went',
#   'back',
#   'climb',
#   'ladder',
#   'ninth',
#   'floor',
#   'walk',
#   'two',
#   'flights',
#   'inside',
#   'later',
#   'looking',
#   'amusement',
#   'park',
#   'came',
#   'end',
#   'bus',
#   'line',
#   'saw',
#   'mother',
#   'sister'],
#  ['saw', 'fur-lined', 'cap', 'put'],
#  ['moved',
#   'mother',
#   'sister',
#   'new',
#   'house',
#   'told',
#   'moved',
#   'house',
#   'right',
#   'away',
#   'tree',
#   'yard',
#   'yard',
#   'hot',
#   'sunny',
#   'experienced',
#   'deep',
#   'feeling',
#   'regret',
#   'stayed',
#   'old',
#   'house',
#   'long',
#   'felt',
#   'hollowness',
#   'pit',
#   'stomach',
#   'later',
#   'told',
#   'mother',
#   'sister',
#   'patients',
#   'group',
#   'psychotherapy',
#   'made',
#   'light',
#   'grievances'],
#  ['sister',
#   'room',
#   'found',
#   'tape',
#   'used',
#   'tape',
#   'box',
#   'containing',
#   'word',
#   'game'],
#  ['right', 'arm', 'burned'],
#  ['auditorium',
#   'mothers',
#   'daughters',
#   'ten',
#   'years',
#   'old',
#   'preparing',
#   'act',
#   'play',
#   'walking',
#   'doll'],
#  ['patient',
#   'hospital',
#   'getting',
#   'undressed',
#   'bed',
#   'difficulty',
#   'clothing',
#   'attendants',
#   'rush'],
#  ['released',
#   'hospital',
#   'felt',
#   'relieved',
#   'home',
#   'later',
#   'building',
#   'narrow',
#   'hall',
#   'go',
#   'hall',
#   'get',
#   'dormitory',
#   'go',
#   'bed',
#   'saw',
#   'hall',
#   'last',
#   'night',
#   'getting',
#   'undressed'],
#  ['sink',
#   'overflowing',
#   'woman',
#   'walked',
#   'room',
#   'urinating',
#   'later',
#   'alley',
#   'found',
#   'football',
#   'schedule',
#   'read',
#   'saw',
#   'shelf',
#   'looked',
#   'like',
#   'food'],
#  ['disassembled',
#   'printing',
#   'press',
#   'power',
#   'accidentally',
#   'turned',
#   'press',
#   'collapsed'],
#  ['printing',
#   'plant',
#   'applying',
#   'work',
#   'reluctant',
#   'speak',
#   'employer',
#   'afraid',
#   'lacked',
#   'experience',
#   'stayed',
#   'employee',
#   'running',
#   'press'],
#  ['room',
#   'door',
#   'ajar',
#   'saw',
#   'woman',
#   'another',
#   'room',
#   'two',
#   'patients',
#   'ward',
#   'named',
#   'dumbler',
#   'farell',
#   'behaving',
#   'like',
#   'homosexuals',
#   'real',
#   'life',
#   'never',
#   'seen',
#   'act',
#   'way',
#   'often',
#   'spoke',
#   'together'],
#  ['found',
#   'money',
#   'building',
#   'allowed',
#   'keep',
#   'later',
#   'lying',
#   'woman',
#   'came',
#   'gave',
#   'bonds',
#   'paper',
#   'foot',
#   'feet',
#   'left',
#   'room',
#   'returned',
#   'gone',
#   'found',
#   'high',
#   'shelf',
#   'spread',
#   'around',
#   'gathered'],
#  ['insert',
#   'something',
#   'something',
#   'written',
#   'later',
#   'sister',
#   'ran',
#   'subway',
#   'missed',
#   'took',
#   'bus',
#   'drove',
#   'streets',
#   'tall',
#   'buildings',
#   'felt',
#   'closed',
#   'wanted',
#   'ride',
#   'sister',
#   'would',
#   'get',
#   'subway',
#   'past',
#   'station',
#   'left',
#   'bus',
#   'worried',
#   'sister',
#   'waiting',
#   'called',
#   'taxi',
#   'foreign',
#   'coins',
#   'paid',
#   'bus',
#   'fare',
#   'foreign',
#   'coins'],
#  ['bed', 'man', 'boy', 'man', 'angry', 'later', 'holding', 'boy', 'arms'],
#  ['sitting',
#   'others',
#   'nun',
#   'came',
#   'served',
#   'us',
#   'food',
#   'left',
#   'recognized',
#   'aunt',
#   'nun'],
#  ['going',
#   'hills',
#   'saw',
#   'boxes',
#   'ground',
#   'wanted',
#   'collect',
#   'someone',
#   'told',
#   'patient',
#   'named',
#   'gonzoles',
#   'put',
#   'purpose'],
#  ['brought',
#   'crutches',
#   'home',
#   'looked',
#   'place',
#   'put',
#   'went',
#   'narrow',
#   'room',
#   'goods',
#   'yarn',
#   'stairway'],
#  ['outside',
#   'hospital',
#   'followed',
#   'patients',
#   'later',
#   'lining',
#   'showers',
#   'clad',
#   'bath',
#   'towels'],
#  ['bathroom', 'little', 'girls', 'paid', 'cents', 'girl', 'show', 'buttocks'],
#  ...]

# %%
dictionary = corpora.Dictionary(tokenized_dreams)
dictionary.filter_extremes(no_below=5, no_above=.5, keep_n=10000)

# %%
corpus = [dictionary.doc2bow(text) for text in tokenized_dreams]

# %%
num_topics=20

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=dictionary,
                                           num_topics=num_topics, 
                                           passes=10,
                                           alpha='auto')

# %%
for i in range(num_topics):
    print("topic %s:\t%s" % (i, ' '.join([term for term, freq in lda_model.show_topic(i, topn=10)])))
# Out:
# topic 0:	friend friends group people girlfriend mine brother university mike sister
# topic 1:	men women ice bob two one cream cabin war f
# topic 2:	car driving road get street bus truck back drive side
# topic 3:	store wearing blue clothes white dress hair shoes black red
# topic 4:	one table box two tape food eat machine put eating
# topic 5:	dog tree gun stephen snow shoot picnic ladder police neighbor
# topic 6:	mary bathroom toilet cat shower knife teeth slide doll sink
# topic 7:	water boat pool plane beach swimming lake fish wally fly
# topic 8:	race keyboard pack win candy roller guard garbage boss 4th
# topic 9:	'm go see get say back walk says 're want
# topic 10:	room house door bed floor living open kitchen bedroom window
# topic 11:	said went came got could saw looked would told back
# topic 12:	mom dad guy like playing stuff movie game ezra watching
# topic 13:	man father baby woman love feel happy frank young kiss
# topic 14:	school class high book teacher college test paper questions read
# topic 15:	got us running ran building big fire run sound around
# topic 16:	horse money bicycle horses tickets bank shift gas alley rode
# topic 17:	something know think trying would time one talking even much
# topic 18:	like going kind know little really remember think thing something
# topic 19:	one see man large small seemed old head long two

# %%
test_book = pd.read_json('EEBO_sample_EF202003/coo.31924013131622.json.bz2', compression = 'bz2')

# %%
test_book
# Out:
#                                                                @context  \
# id                    https://worksets.htrc.illinois.edu/context/ef_...
# type                  https://worksets.htrc.illinois.edu/context/ef_...
# name                  https://worksets.htrc.illinois.edu/context/ef_...
# schemaVersion         https://worksets.htrc.illinois.edu/context/ef_...
# dateCreated           https://worksets.htrc.illinois.edu/context/ef_...
# title                 https://worksets.htrc.illinois.edu/context/ef_...
# contributor           https://worksets.htrc.illinois.edu/context/ef_...
# pubDate               https://worksets.htrc.illinois.edu/context/ef_...
# publisher             https://worksets.htrc.illinois.edu/context/ef_...
# pubPlace              https://worksets.htrc.illinois.edu/context/ef_...
# language              https://worksets.htrc.illinois.edu/context/ef_...
# accessRights          https://worksets.htrc.illinois.edu/context/ef_...
# accessProfile         https://worksets.htrc.illinois.edu/context/ef_...
# sourceInstitution     https://worksets.htrc.illinois.edu/context/ef_...
# mainEntityOfPage      https://worksets.htrc.illinois.edu/context/ef_...
# oclc                  https://worksets.htrc.illinois.edu/context/ef_...
# genre                 https://worksets.htrc.illinois.edu/context/ef_...
# typeOfResource        https://worksets.htrc.illinois.edu/context/ef_...
# lastRightsUpdateDate  https://worksets.htrc.illinois.edu/context/ef_...
# pageCount             https://worksets.htrc.illinois.edu/context/ef_...
# pages                 https://worksets.htrc.illinois.edu/context/ef_...
#
#                                                        schemaVersion  \
# id                    https://schemas.hathitrust.org/EF_Schema_v_3.0
# type                  https://schemas.hathitrust.org/EF_Schema_v_3.0
# name                  https://schemas.hathitrust.org/EF_Schema_v_3.0
# schemaVersion         https://schemas.hathitrust.org/EF_Schema_v_3.0
# dateCreated           https://schemas.hathitrust.org/EF_Schema_v_3.0
# title                 https://schemas.hathitrust.org/EF_Schema_v_3.0
# contributor           https://schemas.hathitrust.org/EF_Schema_v_3.0
# pubDate               https://schemas.hathitrust.org/EF_Schema_v_3.0
# publisher             https://schemas.hathitrust.org/EF_Schema_v_3.0
# pubPlace              https://schemas.hathitrust.org/EF_Schema_v_3.0
# language              https://schemas.hathitrust.org/EF_Schema_v_3.0
# accessRights          https://schemas.hathitrust.org/EF_Schema_v_3.0
# accessProfile         https://schemas.hathitrust.org/EF_Schema_v_3.0
# sourceInstitution     https://schemas.hathitrust.org/EF_Schema_v_3.0
# mainEntityOfPage      https://schemas.hathitrust.org/EF_Schema_v_3.0
# oclc                  https://schemas.hathitrust.org/EF_Schema_v_3.0
# genre                 https://schemas.hathitrust.org/EF_Schema_v_3.0
# typeOfResource        https://schemas.hathitrust.org/EF_Schema_v_3.0
# lastRightsUpdateDate  https://schemas.hathitrust.org/EF_Schema_v_3.0
# pageCount             https://schemas.hathitrust.org/EF_Schema_v_3.0
# pages                 https://schemas.hathitrust.org/EF_Schema_v_3.0
#
#                                                                      id  \
# id                    https://data.analytics.hathitrust.org/extracte...
# type                  https://data.analytics.hathitrust.org/extracte...
# name                  https://data.analytics.hathitrust.org/extracte...
# schemaVersion         https://data.analytics.hathitrust.org/extracte...
# dateCreated           https://data.analytics.hathitrust.org/extracte...
# title                 https://data.analytics.hathitrust.org/extracte...
# contributor           https://data.analytics.hathitrust.org/extracte...
# pubDate               https://data.analytics.hathitrust.org/extracte...
# publisher             https://data.analytics.hathitrust.org/extracte...
# pubPlace              https://data.analytics.hathitrust.org/extracte...
# language              https://data.analytics.hathitrust.org/extracte...
# accessRights          https://data.analytics.hathitrust.org/extracte...
# accessProfile         https://data.analytics.hathitrust.org/extracte...
# sourceInstitution     https://data.analytics.hathitrust.org/extracte...
# mainEntityOfPage      https://data.analytics.hathitrust.org/extracte...
# oclc                  https://data.analytics.hathitrust.org/extracte...
# genre                 https://data.analytics.hathitrust.org/extracte...
# typeOfResource        https://data.analytics.hathitrust.org/extracte...
# lastRightsUpdateDate  https://data.analytics.hathitrust.org/extracte...
# pageCount             https://data.analytics.hathitrust.org/extracte...
# pages                 https://data.analytics.hathitrust.org/extracte...
#
#                                     htid      type  \
# id                    coo.31924013131622  DataFeed
# type                  coo.31924013131622  DataFeed
# name                  coo.31924013131622  DataFeed
# schemaVersion         coo.31924013131622  DataFeed
# dateCreated           coo.31924013131622  DataFeed
# title                 coo.31924013131622  DataFeed
# contributor           coo.31924013131622  DataFeed
# pubDate               coo.31924013131622  DataFeed
# publisher             coo.31924013131622  DataFeed
# pubPlace              coo.31924013131622  DataFeed
# language              coo.31924013131622  DataFeed
# accessRights          coo.31924013131622  DataFeed
# accessProfile         coo.31924013131622  DataFeed
# sourceInstitution     coo.31924013131622  DataFeed
# mainEntityOfPage      coo.31924013131622  DataFeed
# oclc                  coo.31924013131622  DataFeed
# genre                 coo.31924013131622  DataFeed
# typeOfResource        coo.31924013131622  DataFeed
# lastRightsUpdateDate  coo.31924013131622  DataFeed
# pageCount             coo.31924013131622  DataFeed
# pages                 coo.31924013131622  DataFeed
#
#                                              publisher  datePublished  \
# id                    https://analytics.hathitrust.org       20200210
# type                                      Organization       20200210
# name                        HathiTrust Research Center       20200210
# schemaVersion                                      NaN       20200210
# dateCreated                                        NaN       20200210
# title                                              NaN       20200210
# contributor                                        NaN       20200210
# pubDate                                            NaN       20200210
# publisher                                          NaN       20200210
# pubPlace                                           NaN       20200210
# language                                           NaN       20200210
# accessRights                                       NaN       20200210
# accessProfile                                      NaN       20200210
# sourceInstitution                                  NaN       20200210
# mainEntityOfPage                                   NaN       20200210
# oclc                                               NaN       20200210
# genre                                              NaN       20200210
# typeOfResource                                     NaN       20200210
# lastRightsUpdateDate                               NaN       20200210
# pageCount                                          NaN       20200210
# pages                                              NaN       20200210
#
#                                                                metadata  \
# id                        http://hdl.handle.net/2027/coo.31924013131622
# type                                               [DataFeedItem, Book]
# name                                                                NaN
# schemaVersion         https://schemas.hathitrust.org/EF_Schema_Metad...
# dateCreated                                                    20200209
# title                                              The Spanish tragedy,
# contributor           [{'id': 'http://www.viaf.org/viaf/29614087', '...
# pubDate                                                            1898
# publisher             {'id': 'http://catalogdata.library.illinois.ed...
# pubPlace              {'id': 'http://id.loc.gov/vocabulary/countries...
# language                                                            eng
# accessRights                                                         pd
# accessProfile                                                    google
# sourceInstitution     {'type': 'http://id.loc.gov/ontologies/bibfram...
# mainEntityOfPage      [https://catalog.hathitrust.org/Record/0114052...
# oclc                                                           48868264
# genre                           http://id.loc.gov/vocabulary/marcgt/doc
# typeOfResource               http://id.loc.gov/ontologies/bibframe/Text
# lastRightsUpdateDate                                           20200112
# pageCount                                                           NaN
# pages                                                               NaN
#
#                                                                features
# id                        http://hdl.handle.net/2027/coo.31924013131622
# type                                                       DataFeedItem
# name                                                                NaN
# schemaVersion         https://schemas.hathitrust.org/EF_Schema_Featu...
# dateCreated                                                    20200125
# title                                                               NaN
# contributor                                                         NaN
# pubDate                                                             NaN
# publisher                                                           NaN
# pubPlace                                                            NaN
# language                                                            NaN
# accessRights                                                        NaN
# accessProfile                                                       NaN
# sourceInstitution                                                   NaN
# mainEntityOfPage                                                    NaN
# oclc                                                                NaN
# genre                                                               NaN
# typeOfResource                                                      NaN
# lastRightsUpdateDate                                                NaN
# pageCount                                                           204
# pages                 [{'seq': '00000001', 'version': '68b329da9893e...
